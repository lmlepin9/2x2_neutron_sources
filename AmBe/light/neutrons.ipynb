# %% [markdown]
# # AmBe neutron source light analysis

# %%
import h5py
import numpy as np
import h5flow
import matplotlib.pyplot as plt
from matplotlib import cm, colors
# Out:
# WARNING:root:Running without mpi4py because No module named 'mpi4py'

# %%
# DUNE plot style
import sys, os; sys.path.insert(0, os.path.join(os.path.dirname(os.getcwd()), "..", "utils"))
from dune_plot import apply_dune_style, dune_label
apply_dune_style()

# %%
def thd_correct(array):
    """
    Can go to a different file
    Baseline corrects waveforms
    """

    # Define start and end indices
    indices = np.arange(0, 41) * 15  # (39,)
    start_indices, end_indices = indices[:-1], indices[1:]  # (39,)

    segment_range = np.arange(15)  # Shape: (25,)
    index_array = start_indices[:, None] + segment_range  # Shape: (39, 25)

    # Extract data using advanced indexing
    sliced_data = array[..., index_array]
    
    ranges = np.ptp(sliced_data, axis=-1)  # Compute range (n, 8, 64, 39)
    means = np.mean(sliced_data, axis=-1)  # Compute mean (n, 8, 64, 39)

    # Find ordering based on the smallest range
    smallest_ordering = np.argsort(ranges, axis=-1)  # Shape (n, 8, 64, 39)

    # Sort means using the ordering
    sorted_means = np.take_along_axis(means, smallest_ordering, axis=-1)  # Shape (n, 8, 64, 39)
    sorted_range = np.take_along_axis(ranges, smallest_ordering, axis=-1)
    # Compute average of 2nd, 3rd, and 4th smallest means
    average_mean = np.mean(sorted_means[..., 1:4], axis=-1)  # Shape (n, 8, 64)
    expanded_mean = average_mean[..., None] 
    broadcasted_mean = np.tile(expanded_mean, (1, 600))  
    filtered_wvfm = array - broadcasted_mean

    return filtered_wvfm

# %%
# path = '/global/cfs/cdirs/dune/users/lmlepin/2x2_neutron_prod/AmBe_prod_out_cryo_side_v1/FLOW/2x2_MyQGSP_BERT_ArHP_AmBe_AmBe_prod_out_cryo_top_mod0_v1_22.FLOW.hdf5'
# path = '/global/cfs/cdirs/dune/www/data/2x2/nearline_run2/flowed_light/source_ambe_bin0/mod0_threshold_trig/mpd_run_data_rctl_535_p0.FLOW.hdf5'
path = '/global/cfs/cdirs/dune/www/data/2x2/nearline_run2/flowed_charge/ColdOperations/data/2025_Operations_Cold/source/AmBe_0311/packet-0060075-2025_11_03_13_44_24_CST.FLOW.hdf5'
file = h5flow.data.H5FlowDataManager(path, "r")

# %%
keys = h5py.File(path, 'r').keys()
print('keys: ', keys)
for k in keys:
    sub_keys = print('subkeys: ', h5py.File(path, 'r')[k].keys())
# Out:
# keys:  <KeysViewHDF5 ['analysis', 'charge', 'combined', 'geometry_info', 'lar_info', 'run_info']>
# subkeys:  <KeysViewHDF5 ['rock_muon_segments', 'rock_muon_tracks']>
# subkeys:  <KeysViewHDF5 ['calib_prompt_hits', 'events', 'ext_trigs', 'packets', 'packets_corr_ts', 'raw_events', 'raw_hits']>
# subkeys:  <KeysViewHDF5 ['t0']>
# subkeys:  <KeysViewHDF5 ['anode_drift_coordinate', 'det_bounds', 'det_id', 'det_rel_pos', 'det_type', 'disabled_channels', 'disabled_chips', 'drift_dir', 'pixel_coordinates_2D', 'sipm_abs_pos', 'sipm_rel_pos', 'tile_id']>
# subkeys:  <KeysViewHDF5 []>
# subkeys:  <KeysViewHDF5 []>

# %%
file['light/events/data'].dtype.names
# Out:
# ('id', 'event', 'sn', 'utime_ms', 'tai_ns', 'wvfm_valid', 'trig_type')

# %%
a= file["light/wvfm/data"]['samples']
print(a.shape)
# Out:
# (5433, 8, 64, 600)

# %%
a =  thd_correct(a)

# %%
# find an event with a signal: let's look at the waveform with the highest value in the last axis
event, adc, chan, tick = np.unravel_index(np.argmax(a, axis=None), a.shape)
print(event, adc, chan, tick)
# Out:
# 935 5 13 82

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
ax.plot(file['light/wvfm/data'][event]['samples'][adc,chan], alpha=1)
ax.plot(a[event, adc, chan], alpha=0.5, color='red', label='THD Corrected')

# %%
# now find how many waveforms there are that go above threshold
threshold = 10000
n = 0
summary = {}
light = thd_correct(file['light/wvfm/data']['samples'])
for i in range(len(file['light/wvfm/data'])):
    if np.max(light[i]) > threshold:
        n += 1
        # count how many channels are above threshold
        l = 0
        for j in range(8):
            for k in range(64):
                if np.max(light[i][j,k]) > threshold:
                    l += 1
        print(l, 'channels are above', threshold, 'in event', i)
        summary[i] = l
print(n, 'out of', len(file['light/wvfm/data']), 'events have at least one waveform that goes above', threshold)
# Out:
# 2 channels are above 10000 in event 0
# 3 channels are above 10000 in event 1
# 2 channels are above 10000 in event 3
# 1 channels are above 10000 in event 4
# 2 channels are above 10000 in event 7
# 2 channels are above 10000 in event 9
# 2 channels are above 10000 in event 10
# 2 channels are above 10000 in event 11
# 2 channels are above 10000 in event 12
# 2 channels are above 10000 in event 13
# 1 channels are above 10000 in event 14
# 1 channels are above 10000 in event 17
# 1 channels are above 10000 in event 19
# 7 channels are above 10000 in event 20
# 2 channels are above 10000 in event 21
# 1 channels are above 10000 in event 22
# 2 channels are above 10000 in event 23
# 24 channels are above 10000 in event 24
# 15 channels are above 10000 in event 25
# 6 channels are above 10000 in event 26
# 14 channels are above 10000 in event 27
# 1 channels are above 10000 in event 28
# 2 channels are above 10000 in event 29
# 1 channels are above 10000 in event 30
# 4 channels are above 10000 in event 31
# 4 channels are above 10000 in event 32
# 2 channels are above 10000 in event 33
# 15 channels are above 10000 in event 34
# 1 channels are above 10000 in event 37
# 2 channels are above 10000 in event 44
# 1 channels are above 10000 in event 45
# 2 channels are above 10000 in event 48
# 2 channels are above 10000 in event 49
# 1 channels are above 10000 in event 50
# 1 channels are above 10000 in event 52
# 2 channels are above 10000 in event 54
# 2 channels are above 10000 in event 57
# 1 channels are above 10000 in event 58
# 2 channels are above 10000 in event 59
# 2 channels are above 10000 in event 60
# 2 channels are above 10000 in event 63
# 10 channels are above 10000 in event 65
# 2 channels are above 10000 in event 67
# 2 channels are above 10000 in event 68
# 2 channels are above 10000 in event 69
# 1 channels are above 10000 in event 70
# 2 channels are above 10000 in event 75
# 2 channels are above 10000 in event 77
# 2 channels are above 10000 in event 79
# 2 channels are above 10000 in event 80
# 1 channels are above 10000 in event 81
# 1 channels are above 10000 in event 83
# 1 channels are above 10000 in event 84
# 1 channels are above 10000 in event 85
# 1 channels are above 10000 in event 86
# 2 channels are above 10000 in event 87
# 1 channels are above 10000 in event 89
# 1 channels are above 10000 in event 90
# 1 channels are above 10000 in event 91
# 2 channels are above 10000 in event 92
# 1 channels are above 10000 in event 93
# 2 channels are above 10000 in event 94
# 1 channels are above 10000 in event 95
# 2 channels are above 10000 in event 96
# 1 channels are above 10000 in event 97
# 2 channels are above 10000 in event 98
# 17 channels are above 10000 in event 99
# 1 channels are above 10000 in event 103
# 2 channels are above 10000 in event 105
# 2 channels are above 10000 in event 107
# 2 channels are above 10000 in event 108
# 1 channels are above 10000 in event 109
# 2 channels are above 10000 in event 111
# 2 channels are above 10000 in event 112
# 2 channels are above 10000 in event 113
# 24 channels are above 10000 in event 116
# 18 channels are above 10000 in event 119
# 2 channels are above 10000 in event 120
# 1 channels are above 10000 in event 121
# 2 channels are above 10000 in event 122
# 13 channels are above 10000 in event 124
# 1 channels are above 10000 in event 126
# 1 channels are above 10000 in event 127
# 2 channels are above 10000 in event 128
# 2 channels are above 10000 in event 129
# 2 channels are above 10000 in event 130
# 24 channels are above 10000 in event 131
# 1 channels are above 10000 in event 132
# 1 channels are above 10000 in event 133
# 1 channels are above 10000 in event 135
# 2 channels are above 10000 in event 136
# 2 channels are above 10000 in event 137
# 2 channels are above 10000 in event 139
# 1 channels are above 10000 in event 141
# 2 channels are above 10000 in event 142
# 1 channels are above 10000 in event 147
# 1 channels are above 10000 in event 149
# 2 channels are above 10000 in event 150
# 2 channels are above 10000 in event 151
# 2 channels are above 10000 in event 152
# 2 channels are above 10000 in event 155
# 2 channels are above 10000 in event 156
# 1 channels are above 10000 in event 160
# 2 channels are above 10000 in event 161
# 19 channels are above 10000 in event 166
# 14 channels are above 10000 in event 167
# 7 channels are above 10000 in event 168
# 2 channels are above 10000 in event 170
# 1 channels are above 10000 in event 171
# 2 channels are above 10000 in event 175
# 2 channels are above 10000 in event 176
# 1 channels are above 10000 in event 178
# 1 channels are above 10000 in event 179
# 1 channels are above 10000 in event 182
# 2 channels are above 10000 in event 185
# 2 channels are above 10000 in event 187
# 2 channels are above 10000 in event 188
# 1 channels are above 10000 in event 191
# 1 channels are above 10000 in event 192
# 2 channels are above 10000 in event 197
# 2 channels are above 10000 in event 198
# 1 channels are above 10000 in event 199
# 1 channels are above 10000 in event 201
# 2 channels are above 10000 in event 202
# 1 channels are above 10000 in event 203
# 2 channels are above 10000 in event 204
# 19 channels are above 10000 in event 205
# 1 channels are above 10000 in event 206
# 6 channels are above 10000 in event 207
# 2 channels are above 10000 in event 209
# 2 channels are above 10000 in event 211
# 2 channels are above 10000 in event 212
# 9 channels are above 10000 in event 213
# 2 channels are above 10000 in event 215
# 2 channels are above 10000 in event 216
# 2 channels are above 10000 in event 218
# 1 channels are above 10000 in event 221
# 2 channels are above 10000 in event 222
# 2 channels are above 10000 in event 223
# 2 channels are above 10000 in event 225
# 2 channels are above 10000 in event 228
# 1 channels are above 10000 in event 234
# 1 channels are above 10000 in event 235
# 2 channels are above 10000 in event 236
# 2 channels are above 10000 in event 237
# 2 channels are above 10000 in event 239
# 2 channels are above 10000 in event 241
# 1 channels are above 10000 in event 242
# 24 channels are above 10000 in event 247
# 26 channels are above 10000 in event 249
# 2 channels are above 10000 in event 250
# 1 channels are above 10000 in event 252
# 2 channels are above 10000 in event 255
# 2 channels are above 10000 in event 256
# 1 channels are above 10000 in event 257
# 2 channels are above 10000 in event 258
# 2 channels are above 10000 in event 261
# 7 channels are above 10000 in event 262
# 10 channels are above 10000 in event 264
# 2 channels are above 10000 in event 267
# 1 channels are above 10000 in event 268
# 3 channels are above 10000 in event 269
# 2 channels are above 10000 in event 271
# 2 channels are above 10000 in event 272
# 2 channels are above 10000 in event 273
# 18 channels are above 10000 in event 274
# 1 channels are above 10000 in event 275
# 2 channels are above 10000 in event 276
# 6 channels are above 10000 in event 278
# 2 channels are above 10000 in event 280
# 1 channels are above 10000 in event 281
# 1 channels are above 10000 in event 283
# 2 channels are above 10000 in event 284
# 2 channels are above 10000 in event 285
# 2 channels are above 10000 in event 288
# 2 channels are above 10000 in event 289
# 2 channels are above 10000 in event 291
# 2 channels are above 10000 in event 292
# 2 channels are above 10000 in event 294
# 2 channels are above 10000 in event 297
# 2 channels are above 10000 in event 298
# 1 channels are above 10000 in event 300
# 2 channels are above 10000 in event 301
# 2 channels are above 10000 in event 302
# 49 channels are above 10000 in event 303
# 2 channels are above 10000 in event 304
# 15 channels are above 10000 in event 305
# 2 channels are above 10000 in event 307
# 24 channels are above 10000 in event 310
# 2 channels are above 10000 in event 313
# 4 channels are above 10000 in event 314
# 2 channels are above 10000 in event 316
# 2 channels are above 10000 in event 319
# 2 channels are above 10000 in event 320
# 2 channels are above 10000 in event 321
# 2 channels are above 10000 in event 322
# 1 channels are above 10000 in event 323
# 5 channels are above 10000 in event 324
# 2 channels are above 10000 in event 325
# 1 channels are above 10000 in event 326
# 9 channels are above 10000 in event 327
# 1 channels are above 10000 in event 328
# 1 channels are above 10000 in event 330
# 1 channels are above 10000 in event 333
# 2 channels are above 10000 in event 334
# 1 channels are above 10000 in event 336
# 2 channels are above 10000 in event 338
# 1 channels are above 10000 in event 340
# 1 channels are above 10000 in event 344
# 2 channels are above 10000 in event 345
# 6 channels are above 10000 in event 347
# 1 channels are above 10000 in event 349
# 2 channels are above 10000 in event 350
# 2 channels are above 10000 in event 351
# 2 channels are above 10000 in event 352
# 1 channels are above 10000 in event 353
# 2 channels are above 10000 in event 355
# 2 channels are above 10000 in event 356
# 2 channels are above 10000 in event 357
# 2 channels are above 10000 in event 359
# 6 channels are above 10000 in event 360
# 2 channels are above 10000 in event 361
# 2 channels are above 10000 in event 362
# 8 channels are above 10000 in event 363
# 2 channels are above 10000 in event 364
# 1 channels are above 10000 in event 365
# 2 channels are above 10000 in event 366
# 1 channels are above 10000 in event 369
# 2 channels are above 10000 in event 370
# 2 channels are above 10000 in event 371
# 1 channels are above 10000 in event 372
# 2 channels are above 10000 in event 374
# 8 channels are above 10000 in event 375
# 2 channels are above 10000 in event 376
# 1 channels are above 10000 in event 377
# 1 channels are above 10000 in event 378
# 2 channels are above 10000 in event 380
# 1 channels are above 10000 in event 381
# 15 channels are above 10000 in event 382
# 1 channels are above 10000 in event 383
# 1 channels are above 10000 in event 385
# 2 channels are above 10000 in event 386
# 2 channels are above 10000 in event 387
# 4 channels are above 10000 in event 388
# 12 channels are above 10000 in event 389
# 1 channels are above 10000 in event 394
# 2 channels are above 10000 in event 395
# 2 channels are above 10000 in event 397
# 1 channels are above 10000 in event 398
# 1 channels are above 10000 in event 399
# 2 channels are above 10000 in event 400
# 1 channels are above 10000 in event 401
# 1 channels are above 10000 in event 402
# 2 channels are above 10000 in event 403
# 2 channels are above 10000 in event 404
# 2 channels are above 10000 in event 406
# 2 channels are above 10000 in event 408
# 1 channels are above 10000 in event 411
# 1 channels are above 10000 in event 412
# 10 channels are above 10000 in event 413
# 2 channels are above 10000 in event 416
# 2 channels are above 10000 in event 418
# 1 channels are above 10000 in event 419
# 1 channels are above 10000 in event 421
# 2 channels are above 10000 in event 424
# 1 channels are above 10000 in event 427
# 2 channels are above 10000 in event 429
# 2 channels are above 10000 in event 431
# 1 channels are above 10000 in event 432
# 10 channels are above 10000 in event 436
# 2 channels are above 10000 in event 438
# 1 channels are above 10000 in event 444
# 1 channels are above 10000 in event 446
# 2 channels are above 10000 in event 449
# 1 channels are above 10000 in event 450
# 1 channels are above 10000 in event 451
# 2 channels are above 10000 in event 452
# 2 channels are above 10000 in event 453
# 1 channels are above 10000 in event 454
# 1 channels are above 10000 in event 456
# 2 channels are above 10000 in event 461
# 2 channels are above 10000 in event 463
# 2 channels are above 10000 in event 464
# 4 channels are above 10000 in event 465
# 2 channels are above 10000 in event 467
# 1 channels are above 10000 in event 469
# 1 channels are above 10000 in event 470
# 1 channels are above 10000 in event 471
# 2 channels are above 10000 in event 472
# 1 channels are above 10000 in event 473
# 1 channels are above 10000 in event 474
# 1 channels are above 10000 in event 476
# 1 channels are above 10000 in event 477
# 2 channels are above 10000 in event 479
# 2 channels are above 10000 in event 480
# 2 channels are above 10000 in event 481
# 16 channels are above 10000 in event 483
# 2 channels are above 10000 in event 484
# 2 channels are above 10000 in event 486
# 2 channels are above 10000 in event 487
# 2 channels are above 10000 in event 488
# 2 channels are above 10000 in event 491
# 1 channels are above 10000 in event 493
# 2 channels are above 10000 in event 494
# 2 channels are above 10000 in event 497
# 1 channels are above 10000 in event 498
# 15 channels are above 10000 in event 501
# 1 channels are above 10000 in event 504
# 2 channels are above 10000 in event 506
# 2 channels are above 10000 in event 508
# 2 channels are above 10000 in event 510
# 2 channels are above 10000 in event 511
# 1 channels are above 10000 in event 513
# 2 channels are above 10000 in event 517
# 2 channels are above 10000 in event 519
# 1 channels are above 10000 in event 520
# 2 channels are above 10000 in event 521
# 2 channels are above 10000 in event 524
# 2 channels are above 10000 in event 525
# 1 channels are above 10000 in event 527
# 1 channels are above 10000 in event 528
# 1 channels are above 10000 in event 529
# 6 channels are above 10000 in event 532
# 2 channels are above 10000 in event 536
# 1 channels are above 10000 in event 537
# 2 channels are above 10000 in event 539
# 1 channels are above 10000 in event 542
# 2 channels are above 10000 in event 544
# 18 channels are above 10000 in event 545
# 2 channels are above 10000 in event 546
# 1 channels are above 10000 in event 547
# 2 channels are above 10000 in event 549
# 1 channels are above 10000 in event 551
# 1 channels are above 10000 in event 553
# 1 channels are above 10000 in event 555
# 2 channels are above 10000 in event 559
# 1 channels are above 10000 in event 561
# 2 channels are above 10000 in event 562
# 2 channels are above 10000 in event 563
# 2 channels are above 10000 in event 566
# 1 channels are above 10000 in event 567
# 1 channels are above 10000 in event 568
# 2 channels are above 10000 in event 571
# 1 channels are above 10000 in event 572
# 2 channels are above 10000 in event 574
# 2 channels are above 10000 in event 576
# 8 channels are above 10000 in event 577
# 2 channels are above 10000 in event 578
# 47 channels are above 10000 in event 579
# 4 channels are above 10000 in event 583
# 1 channels are above 10000 in event 585
# 11 channels are above 10000 in event 589
# 2 channels are above 10000 in event 590
# 4 channels are above 10000 in event 592
# 2 channels are above 10000 in event 594
# 1 channels are above 10000 in event 596
# 2 channels are above 10000 in event 597
# 1 channels are above 10000 in event 600
# 2 channels are above 10000 in event 602
# 2 channels are above 10000 in event 603
# 2 channels are above 10000 in event 606
# 2 channels are above 10000 in event 607
# 1 channels are above 10000 in event 608
# 2 channels are above 10000 in event 609
# 7 channels are above 10000 in event 611
# 2 channels are above 10000 in event 612
# 1 channels are above 10000 in event 613
# 2 channels are above 10000 in event 614
# 2 channels are above 10000 in event 616
# 2 channels are above 10000 in event 617
# 3 channels are above 10000 in event 618
# 2 channels are above 10000 in event 619
# 1 channels are above 10000 in event 621
# 19 channels are above 10000 in event 623
# 7 channels are above 10000 in event 624
# 2 channels are above 10000 in event 626
# 1 channels are above 10000 in event 627
# 2 channels are above 10000 in event 628
# 1 channels are above 10000 in event 633
# 7 channels are above 10000 in event 634
# 2 channels are above 10000 in event 636
# 2 channels are above 10000 in event 640
# 2 channels are above 10000 in event 641
# 8 channels are above 10000 in event 642
# 78 channels are above 10000 in event 643
# 2 channels are above 10000 in event 645
# 2 channels are above 10000 in event 646
# 1 channels are above 10000 in event 648
# 2 channels are above 10000 in event 649
# 7 channels are above 10000 in event 650
# 2 channels are above 10000 in event 652
# 2 channels are above 10000 in event 653
# 2 channels are above 10000 in event 654
# 16 channels are above 10000 in event 657
# 2 channels are above 10000 in event 658
# 2 channels are above 10000 in event 659
# 2 channels are above 10000 in event 660
# 2 channels are above 10000 in event 662
# 2 channels are above 10000 in event 663
# 1 channels are above 10000 in event 664
# 2 channels are above 10000 in event 665
# 1 channels are above 10000 in event 667
# 2 channels are above 10000 in event 668
# 2 channels are above 10000 in event 670
# 2 channels are above 10000 in event 671
# 3 channels are above 10000 in event 672
# 2 channels are above 10000 in event 673
# 3 channels are above 10000 in event 674
# 1 channels are above 10000 in event 675
# 7 channels are above 10000 in event 676
# 13 channels are above 10000 in event 677
# 1 channels are above 10000 in event 679
# 2 channels are above 10000 in event 681
# 2 channels are above 10000 in event 683
# 2 channels are above 10000 in event 684
# 2 channels are above 10000 in event 686
# 2 channels are above 10000 in event 689
# 1 channels are above 10000 in event 690
# 1 channels are above 10000 in event 691
# 23 channels are above 10000 in event 692
# 2 channels are above 10000 in event 698
# 2 channels are above 10000 in event 700
# 6 channels are above 10000 in event 702
# 1 channels are above 10000 in event 703
# 2 channels are above 10000 in event 704
# 2 channels are above 10000 in event 705
# 1 channels are above 10000 in event 706
# 2 channels are above 10000 in event 709
# 13 channels are above 10000 in event 710
# 23 channels are above 10000 in event 713
# 1 channels are above 10000 in event 716
# 7 channels are above 10000 in event 717
# 2 channels are above 10000 in event 718
# 1 channels are above 10000 in event 719
# 2 channels are above 10000 in event 720
# 1 channels are above 10000 in event 722
# 2 channels are above 10000 in event 723
# 2 channels are above 10000 in event 724
# 2 channels are above 10000 in event 727
# 2 channels are above 10000 in event 728
# 2 channels are above 10000 in event 730
# 25 channels are above 10000 in event 731
# 7 channels are above 10000 in event 732
# 3 channels are above 10000 in event 733
# 2 channels are above 10000 in event 735
# 7 channels are above 10000 in event 738
# 1 channels are above 10000 in event 739
# 1 channels are above 10000 in event 740
# 2 channels are above 10000 in event 745
# 2 channels are above 10000 in event 746
# 13 channels are above 10000 in event 747
# 1 channels are above 10000 in event 748
# 2 channels are above 10000 in event 750
# 2 channels are above 10000 in event 752
# 2 channels are above 10000 in event 753
# 2 channels are above 10000 in event 754
# 2 channels are above 10000 in event 755
# 1 channels are above 10000 in event 756
# 1 channels are above 10000 in event 759
# 2 channels are above 10000 in event 762
# 2 channels are above 10000 in event 764
# 15 channels are above 10000 in event 765
# 2 channels are above 10000 in event 769
# 2 channels are above 10000 in event 770
# 2 channels are above 10000 in event 771
# 2 channels are above 10000 in event 772
# 2 channels are above 10000 in event 775
# 1 channels are above 10000 in event 776
# 2 channels are above 10000 in event 777
# 2 channels are above 10000 in event 778
# 2 channels are above 10000 in event 779
# 41 channels are above 10000 in event 780
# 2 channels are above 10000 in event 782
# 2 channels are above 10000 in event 783
# 2 channels are above 10000 in event 784
# 2 channels are above 10000 in event 786
# 1 channels are above 10000 in event 787
# 2 channels are above 10000 in event 791
# 1 channels are above 10000 in event 792
# 1 channels are above 10000 in event 795
# 1 channels are above 10000 in event 797
# 1 channels are above 10000 in event 799
# 4 channels are above 10000 in event 800
# 1 channels are above 10000 in event 801
# 1 channels are above 10000 in event 803
# 2 channels are above 10000 in event 804
# 2 channels are above 10000 in event 805
# 1 channels are above 10000 in event 806
# 1 channels are above 10000 in event 807
# 16 channels are above 10000 in event 808
# 1 channels are above 10000 in event 809
# 2 channels are above 10000 in event 810
# 1 channels are above 10000 in event 811
# 1 channels are above 10000 in event 813
# 1 channels are above 10000 in event 815
# 1 channels are above 10000 in event 817
# 34 channels are above 10000 in event 818
# 1 channels are above 10000 in event 825
# 2 channels are above 10000 in event 826
# 2 channels are above 10000 in event 827
# 2 channels are above 10000 in event 828
# 2 channels are above 10000 in event 829
# 1 channels are above 10000 in event 830
# 1 channels are above 10000 in event 831
# 1 channels are above 10000 in event 832
# 1 channels are above 10000 in event 834
# 2 channels are above 10000 in event 835
# 2 channels are above 10000 in event 836
# 2 channels are above 10000 in event 837
# 1 channels are above 10000 in event 838
# 1 channels are above 10000 in event 840
# 24 channels are above 10000 in event 842
# 2 channels are above 10000 in event 844
# 16 channels are above 10000 in event 846
# 5 channels are above 10000 in event 848
# 1 channels are above 10000 in event 849
# 36 channels are above 10000 in event 853
# 1 channels are above 10000 in event 854
# 2 channels are above 10000 in event 855
# 2 channels are above 10000 in event 857
# 2 channels are above 10000 in event 859
# 2 channels are above 10000 in event 860
# 2 channels are above 10000 in event 862
# 2 channels are above 10000 in event 863
# 1 channels are above 10000 in event 864
# 1 channels are above 10000 in event 866
# 1 channels are above 10000 in event 867
# 2 channels are above 10000 in event 869
# 1 channels are above 10000 in event 870
# 5 channels are above 10000 in event 877
# 2 channels are above 10000 in event 879
# 10 channels are above 10000 in event 881
# 1 channels are above 10000 in event 882
# 2 channels are above 10000 in event 883
# 1 channels are above 10000 in event 884
# 1 channels are above 10000 in event 885
# 2 channels are above 10000 in event 886
# 2 channels are above 10000 in event 889
# 1 channels are above 10000 in event 894
# 22 channels are above 10000 in event 895
# 2 channels are above 10000 in event 896
# 6 channels are above 10000 in event 897
# 2 channels are above 10000 in event 898
# 1 channels are above 10000 in event 900
# 1 channels are above 10000 in event 901
# 2 channels are above 10000 in event 903
# 1 channels are above 10000 in event 904
# 2 channels are above 10000 in event 906
# 1 channels are above 10000 in event 908
# 2 channels are above 10000 in event 910
# 1 channels are above 10000 in event 911
# 1 channels are above 10000 in event 915
# 2 channels are above 10000 in event 916
# 2 channels are above 10000 in event 918
# 2 channels are above 10000 in event 919
# 1 channels are above 10000 in event 920
# 1 channels are above 10000 in event 924
# 2 channels are above 10000 in event 925
# 1 channels are above 10000 in event 928
# 2 channels are above 10000 in event 930
# 95 channels are above 10000 in event 935
# 2 channels are above 10000 in event 937
# 1 channels are above 10000 in event 938
# 1 channels are above 10000 in event 939
# 2 channels are above 10000 in event 940
# 1 channels are above 10000 in event 942
# 2 channels are above 10000 in event 946
# 2 channels are above 10000 in event 947
# 2 channels are above 10000 in event 948
# 1 channels are above 10000 in event 949
# 1 channels are above 10000 in event 950
# 26 channels are above 10000 in event 954
# 2 channels are above 10000 in event 958
# 1 channels are above 10000 in event 961
# 1 channels are above 10000 in event 963
# 2 channels are above 10000 in event 965
# 17 channels are above 10000 in event 967
# 13 channels are above 10000 in event 968
# 2 channels are above 10000 in event 969
# 2 channels are above 10000 in event 970
# 23 channels are above 10000 in event 971
# 1 channels are above 10000 in event 972
# 2 channels are above 10000 in event 973
# 2 channels are above 10000 in event 976
# 2 channels are above 10000 in event 977
# 2 channels are above 10000 in event 978
# 1 channels are above 10000 in event 979
# 1 channels are above 10000 in event 982
# 1 channels are above 10000 in event 984
# 1 channels are above 10000 in event 985
# 2 channels are above 10000 in event 986
# 2 channels are above 10000 in event 987
# 1 channels are above 10000 in event 988
# 1 channels are above 10000 in event 989
# 2 channels are above 10000 in event 991
# 2 channels are above 10000 in event 992
# 2 channels are above 10000 in event 993
# 2 channels are above 10000 in event 994
# 2 channels are above 10000 in event 995
# 1 channels are above 10000 in event 996
# 2 channels are above 10000 in event 998
# 1 channels are above 10000 in event 999
# 1 channels are above 10000 in event 1000
# 2 channels are above 10000 in event 1002
# 1 channels are above 10000 in event 1004
# 2 channels are above 10000 in event 1005
# 1 channels are above 10000 in event 1007
# 1 channels are above 10000 in event 1008
# 1 channels are above 10000 in event 1009
# 1 channels are above 10000 in event 1010
# 1 channels are above 10000 in event 1011
# 2 channels are above 10000 in event 1012
# 1 channels are above 10000 in event 1014
# 1 channels are above 10000 in event 1016
# 13 channels are above 10000 in event 1018
# 1 channels are above 10000 in event 1022
# 1 channels are above 10000 in event 1024
# 2 channels are above 10000 in event 1026
# 2 channels are above 10000 in event 1029
# 2 channels are above 10000 in event 1030
# 2 channels are above 10000 in event 1032
# 9 channels are above 10000 in event 1035
# 1 channels are above 10000 in event 1038
# 1 channels are above 10000 in event 1040
# 1 channels are above 10000 in event 1041
# 1 channels are above 10000 in event 1043
# 2 channels are above 10000 in event 1044
# 2 channels are above 10000 in event 1045
# 2 channels are above 10000 in event 1048
# 2 channels are above 10000 in event 1049
# 2 channels are above 10000 in event 1050
# 2 channels are above 10000 in event 1051
# 23 channels are above 10000 in event 1052
# 1 channels are above 10000 in event 1055
# 1 channels are above 10000 in event 1059
# 2 channels are above 10000 in event 1060
# 6 channels are above 10000 in event 1061
# 3 channels are above 10000 in event 1062
# 1 channels are above 10000 in event 1065
# 2 channels are above 10000 in event 1066
# 2 channels are above 10000 in event 1075
# 2 channels are above 10000 in event 1076
# 2 channels are above 10000 in event 1077
# 2 channels are above 10000 in event 1078
# 17 channels are above 10000 in event 1080
# 1 channels are above 10000 in event 1081
# 1 channels are above 10000 in event 1082
# 2 channels are above 10000 in event 1083
# 2 channels are above 10000 in event 1088
# 1 channels are above 10000 in event 1090
# 4 channels are above 10000 in event 1091
# 1 channels are above 10000 in event 1092
# 2 channels are above 10000 in event 1093
# 3 channels are above 10000 in event 1094
# 1 channels are above 10000 in event 1095
# 1 channels are above 10000 in event 1096
# 2 channels are above 10000 in event 1097
# 2 channels are above 10000 in event 1098
# 2 channels are above 10000 in event 1100
# 2 channels are above 10000 in event 1101
# 1 channels are above 10000 in event 1102
# 2 channels are above 10000 in event 1103
# 6 channels are above 10000 in event 1104
# 34 channels are above 10000 in event 1105
# 1 channels are above 10000 in event 1108
# 2 channels are above 10000 in event 1109
# 2 channels are above 10000 in event 1110
# 1 channels are above 10000 in event 1112
# 9 channels are above 10000 in event 1113
# 2 channels are above 10000 in event 1114
# 2 channels are above 10000 in event 1115
# 1 channels are above 10000 in event 1116
# 13 channels are above 10000 in event 1118
# 30 channels are above 10000 in event 1120
# 2 channels are above 10000 in event 1122
# 1 channels are above 10000 in event 1125
# 2 channels are above 10000 in event 1127
# 13 channels are above 10000 in event 1128
# 8 channels are above 10000 in event 1129
# 2 channels are above 10000 in event 1130
# 2 channels are above 10000 in event 1131
# 2 channels are above 10000 in event 1132
# 1 channels are above 10000 in event 1133
# 2 channels are above 10000 in event 1135
# 2 channels are above 10000 in event 1136
# 37 channels are above 10000 in event 1137
# 2 channels are above 10000 in event 1138
# 2 channels are above 10000 in event 1140
# 1 channels are above 10000 in event 1145
# 2 channels are above 10000 in event 1147
# 1 channels are above 10000 in event 1148
# 2 channels are above 10000 in event 1149
# 2 channels are above 10000 in event 1150
# 2 channels are above 10000 in event 1152
# 1 channels are above 10000 in event 1154
# 1 channels are above 10000 in event 1155
# 2 channels are above 10000 in event 1156
# 1 channels are above 10000 in event 1158
# 2 channels are above 10000 in event 1160
# 2 channels are above 10000 in event 1163
# 2 channels are above 10000 in event 1168
# 2 channels are above 10000 in event 1169
# 1 channels are above 10000 in event 1170
# 2 channels are above 10000 in event 1171
# 2 channels are above 10000 in event 1172
# 1 channels are above 10000 in event 1173
# 2 channels are above 10000 in event 1175
# 1 channels are above 10000 in event 1176
# 1 channels are above 10000 in event 1177
# 1 channels are above 10000 in event 1179
# 2 channels are above 10000 in event 1180
# 12 channels are above 10000 in event 1181
# 1 channels are above 10000 in event 1183
# 2 channels are above 10000 in event 1184
# 34 channels are above 10000 in event 1188
# 2 channels are above 10000 in event 1189
# 2 channels are above 10000 in event 1190
# 2 channels are above 10000 in event 1193
# 9 channels are above 10000 in event 1195
# 2 channels are above 10000 in event 1196
# 2 channels are above 10000 in event 1197
# 2 channels are above 10000 in event 1199
# 1 channels are above 10000 in event 1201
# 2 channels are above 10000 in event 1205
# 2 channels are above 10000 in event 1206
# 1 channels are above 10000 in event 1208
# 2 channels are above 10000 in event 1210
# 2 channels are above 10000 in event 1211
# 2 channels are above 10000 in event 1217
# 1 channels are above 10000 in event 1218
# 1 channels are above 10000 in event 1219
# 1 channels are above 10000 in event 1221
# 1 channels are above 10000 in event 1223
# 2 channels are above 10000 in event 1225
# 2 channels are above 10000 in event 1226
# 1 channels are above 10000 in event 1232
# 3 channels are above 10000 in event 1234
# 1 channels are above 10000 in event 1235
# 2 channels are above 10000 in event 1238
# 2 channels are above 10000 in event 1241
# 1 channels are above 10000 in event 1242
# 1 channels are above 10000 in event 1243
# 1 channels are above 10000 in event 1244
# 1 channels are above 10000 in event 1245
# 2 channels are above 10000 in event 1246
# 2 channels are above 10000 in event 1247
# 2 channels are above 10000 in event 1248
# 2 channels are above 10000 in event 1249
# 2 channels are above 10000 in event 1250
# 37 channels are above 10000 in event 1253
# 7 channels are above 10000 in event 1254
# 2 channels are above 10000 in event 1255
# 2 channels are above 10000 in event 1256
# 2 channels are above 10000 in event 1257
# 2 channels are above 10000 in event 1259
# 2 channels are above 10000 in event 1260
# 10 channels are above 10000 in event 1261
# 1 channels are above 10000 in event 1262
# 2 channels are above 10000 in event 1265
# 2 channels are above 10000 in event 1266
# 1 channels are above 10000 in event 1274
# 2 channels are above 10000 in event 1277
# 1 channels are above 10000 in event 1281
# 2 channels are above 10000 in event 1282
# 1 channels are above 10000 in event 1285
# 2 channels are above 10000 in event 1287
# 2 channels are above 10000 in event 1288
# 2 channels are above 10000 in event 1289
# 17 channels are above 10000 in event 1292
# 2 channels are above 10000 in event 1293
# 2 channels are above 10000 in event 1294
# 2 channels are above 10000 in event 1296
# 1 channels are above 10000 in event 1298
# 1 channels are above 10000 in event 1302
# 1 channels are above 10000 in event 1303
# 2 channels are above 10000 in event 1305
# 1 channels are above 10000 in event 1306
# 1 channels are above 10000 in event 1307
# 2 channels are above 10000 in event 1308
# 2 channels are above 10000 in event 1310
# 2 channels are above 10000 in event 1312
# 6 channels are above 10000 in event 1313
# 1 channels are above 10000 in event 1314
# 2 channels are above 10000 in event 1317
# 10 channels are above 10000 in event 1318
# 1 channels are above 10000 in event 1319
# 2 channels are above 10000 in event 1320
# 2 channels are above 10000 in event 1322
# 18 channels are above 10000 in event 1323
# 2 channels are above 10000 in event 1324
# 1 channels are above 10000 in event 1326
# 1 channels are above 10000 in event 1327
# 2 channels are above 10000 in event 1328
# 2 channels are above 10000 in event 1329
# 2 channels are above 10000 in event 1330
# 1 channels are above 10000 in event 1331
# 1 channels are above 10000 in event 1332
# 2 channels are above 10000 in event 1335
# 2 channels are above 10000 in event 1336
# 2 channels are above 10000 in event 1339
# 2 channels are above 10000 in event 1342
# 2 channels are above 10000 in event 1343
# 1 channels are above 10000 in event 1344
# 1 channels are above 10000 in event 1346
# 1 channels are above 10000 in event 1347
# 2 channels are above 10000 in event 1349
# 2 channels are above 10000 in event 1352
# 2 channels are above 10000 in event 1353
# 2 channels are above 10000 in event 1354
# 2 channels are above 10000 in event 1355
# 1 channels are above 10000 in event 1357
# 2 channels are above 10000 in event 1358
# 10 channels are above 10000 in event 1360
# 25 channels are above 10000 in event 1361
# 1 channels are above 10000 in event 1364
# 1 channels are above 10000 in event 1365
# 11 channels are above 10000 in event 1371
# 2 channels are above 10000 in event 1372
# 1 channels are above 10000 in event 1374
# 1 channels are above 10000 in event 1375
# 2 channels are above 10000 in event 1376
# 1 channels are above 10000 in event 1380
# 2 channels are above 10000 in event 1381
# 2 channels are above 10000 in event 1383
# 1 channels are above 10000 in event 1384
# 2 channels are above 10000 in event 1386
# 1 channels are above 10000 in event 1387
# 2 channels are above 10000 in event 1390
# 2 channels are above 10000 in event 1391
# 2 channels are above 10000 in event 1392
# 2 channels are above 10000 in event 1393
# 2 channels are above 10000 in event 1394
# 1 channels are above 10000 in event 1395
# 1 channels are above 10000 in event 1397
# 1 channels are above 10000 in event 1401
# 2 channels are above 10000 in event 1404
# 2 channels are above 10000 in event 1405
# 17 channels are above 10000 in event 1408
# 2 channels are above 10000 in event 1409
# 2 channels are above 10000 in event 1410
# 1 channels are above 10000 in event 1411
# 1 channels are above 10000 in event 1414
# 2 channels are above 10000 in event 1417
# 1 channels are above 10000 in event 1420
# 6 channels are above 10000 in event 1421
# 1 channels are above 10000 in event 1423
# 4 channels are above 10000 in event 1424
# 2 channels are above 10000 in event 1425
# 2 channels are above 10000 in event 1427
# 1 channels are above 10000 in event 1428
# 4 channels are above 10000 in event 1429
# 16 channels are above 10000 in event 1430
# 6 channels are above 10000 in event 1431
# 2 channels are above 10000 in event 1432
# 2 channels are above 10000 in event 1434
# 2 channels are above 10000 in event 1436
# 2 channels are above 10000 in event 1437
# 5 channels are above 10000 in event 1438
# 1 channels are above 10000 in event 1439
# 1 channels are above 10000 in event 1441
# 1 channels are above 10000 in event 1442
# 1 channels are above 10000 in event 1444
# 2 channels are above 10000 in event 1445
# 1 channels are above 10000 in event 1449
# 2 channels are above 10000 in event 1450
# 2 channels are above 10000 in event 1451
# 2 channels are above 10000 in event 1452
# 1 channels are above 10000 in event 1453
# 1 channels are above 10000 in event 1457
# 1 channels are above 10000 in event 1459
# 2 channels are above 10000 in event 1460
# 1 channels are above 10000 in event 1461
# 16 channels are above 10000 in event 1462
# 2 channels are above 10000 in event 1465
# 2 channels are above 10000 in event 1468
# 4 channels are above 10000 in event 1472
# 2 channels are above 10000 in event 1473
# 1 channels are above 10000 in event 1475
# 23 channels are above 10000 in event 1478
# 2 channels are above 10000 in event 1479
# 2 channels are above 10000 in event 1481
# 2 channels are above 10000 in event 1482
# 31 channels are above 10000 in event 1484
# 2 channels are above 10000 in event 1485
# 6 channels are above 10000 in event 1486
# 1 channels are above 10000 in event 1487
# 1 channels are above 10000 in event 1488
# 1 channels are above 10000 in event 1490
# 1 channels are above 10000 in event 1491
# 2 channels are above 10000 in event 1492
# 2 channels are above 10000 in event 1494
# 15 channels are above 10000 in event 1495
# 2 channels are above 10000 in event 1496
# 1 channels are above 10000 in event 1497
# 2 channels are above 10000 in event 1498
# 1 channels are above 10000 in event 1499
# 2 channels are above 10000 in event 1501
# 2 channels are above 10000 in event 1502
# 4 channels are above 10000 in event 1504
# 2 channels are above 10000 in event 1505
# 2 channels are above 10000 in event 1506
# 3 channels are above 10000 in event 1507
# 1 channels are above 10000 in event 1508
# 2 channels are above 10000 in event 1509
# 1 channels are above 10000 in event 1511
# 1 channels are above 10000 in event 1512
# 11 channels are above 10000 in event 1513
# 2 channels are above 10000 in event 1517
# 2 channels are above 10000 in event 1518
# 2 channels are above 10000 in event 1519
# 1 channels are above 10000 in event 1523
# 2 channels are above 10000 in event 1524
# 1 channels are above 10000 in event 1525
# 2 channels are above 10000 in event 1526
# 1 channels are above 10000 in event 1527
# 2 channels are above 10000 in event 1529
# 2 channels are above 10000 in event 1532
# 1 channels are above 10000 in event 1533
# 1 channels are above 10000 in event 1536
# 3 channels are above 10000 in event 1537
# 1 channels are above 10000 in event 1539
# 1 channels are above 10000 in event 1540
# 2 channels are above 10000 in event 1542
# 8 channels are above 10000 in event 1545
# 12 channels are above 10000 in event 1548
# 2 channels are above 10000 in event 1549
# 2 channels are above 10000 in event 1550
# 2 channels are above 10000 in event 1551
# 2 channels are above 10000 in event 1552
# 2 channels are above 10000 in event 1553
# 11 channels are above 10000 in event 1554
# 1 channels are above 10000 in event 1555
# 2 channels are above 10000 in event 1559
# 3 channels are above 10000 in event 1560
# 2 channels are above 10000 in event 1561
# 1 channels are above 10000 in event 1563
# 1 channels are above 10000 in event 1564
# 2 channels are above 10000 in event 1565
# 2 channels are above 10000 in event 1566
# 2 channels are above 10000 in event 1570
# 2 channels are above 10000 in event 1572
# 2 channels are above 10000 in event 1573
# 22 channels are above 10000 in event 1574
# 1 channels are above 10000 in event 1577
# 1 channels are above 10000 in event 1578
# 2 channels are above 10000 in event 1579
# 1 channels are above 10000 in event 1580
# 2 channels are above 10000 in event 1583
# 1 channels are above 10000 in event 1585
# 1 channels are above 10000 in event 1586
# 2 channels are above 10000 in event 1587
# 2 channels are above 10000 in event 1588
# 2 channels are above 10000 in event 1589
# 1 channels are above 10000 in event 1590
# 1 channels are above 10000 in event 1591
# 1 channels are above 10000 in event 1592
# 2 channels are above 10000 in event 1593
# 2 channels are above 10000 in event 1594
# 2 channels are above 10000 in event 1595
# 27 channels are above 10000 in event 1598
# 2 channels are above 10000 in event 1600
# 2 channels are above 10000 in event 1601
# 2 channels are above 10000 in event 1602
# 1 channels are above 10000 in event 1606
# 2 channels are above 10000 in event 1607
# 2 channels are above 10000 in event 1608
# 6 channels are above 10000 in event 1609
# 1 channels are above 10000 in event 1610
# 2 channels are above 10000 in event 1611
# 1 channels are above 10000 in event 1612
# 1 channels are above 10000 in event 1613
# 2 channels are above 10000 in event 1615
# 2 channels are above 10000 in event 1616
# 2 channels are above 10000 in event 1618
# 2 channels are above 10000 in event 1619
# 2 channels are above 10000 in event 1621
# 1 channels are above 10000 in event 1623
# 2 channels are above 10000 in event 1625
# 2 channels are above 10000 in event 1626
# 2 channels are above 10000 in event 1629
# 1 channels are above 10000 in event 1630
# 1 channels are above 10000 in event 1633
# 2 channels are above 10000 in event 1634
# 1 channels are above 10000 in event 1635
# 1 channels are above 10000 in event 1636
# 2 channels are above 10000 in event 1638
# 1 channels are above 10000 in event 1639
# 2 channels are above 10000 in event 1640
# 1 channels are above 10000 in event 1641
# 1 channels are above 10000 in event 1642
# 2 channels are above 10000 in event 1644
# 2 channels are above 10000 in event 1647
# 2 channels are above 10000 in event 1649
# 2 channels are above 10000 in event 1651
# 2 channels are above 10000 in event 1654
# 3 channels are above 10000 in event 1655
# 1 channels are above 10000 in event 1656
# 22 channels are above 10000 in event 1659
# 1 channels are above 10000 in event 1662
# 35 channels are above 10000 in event 1664
# 1 channels are above 10000 in event 1665
# 2 channels are above 10000 in event 1666
# 2 channels are above 10000 in event 1667
# 2 channels are above 10000 in event 1668
# 2 channels are above 10000 in event 1670
# 2 channels are above 10000 in event 1672
# 2 channels are above 10000 in event 1673
# 1 channels are above 10000 in event 1674
# 1 channels are above 10000 in event 1675
# 2 channels are above 10000 in event 1678
# 2 channels are above 10000 in event 1680
# 1 channels are above 10000 in event 1681
# 1 channels are above 10000 in event 1682
# 1 channels are above 10000 in event 1684
# 1 channels are above 10000 in event 1685
# 1 channels are above 10000 in event 1686
# 2 channels are above 10000 in event 1687
# 1 channels are above 10000 in event 1688
# 1 channels are above 10000 in event 1690
# 2 channels are above 10000 in event 1694
# 2 channels are above 10000 in event 1695
# 1 channels are above 10000 in event 1701
# 2 channels are above 10000 in event 1706
# 1 channels are above 10000 in event 1707
# 2 channels are above 10000 in event 1709
# 2 channels are above 10000 in event 1711
# 6 channels are above 10000 in event 1714
# 1 channels are above 10000 in event 1715
# 2 channels are above 10000 in event 1716
# 1 channels are above 10000 in event 1717
# 2 channels are above 10000 in event 1718
# 2 channels are above 10000 in event 1719
# 2 channels are above 10000 in event 1721
# 2 channels are above 10000 in event 1723
# 2 channels are above 10000 in event 1725
# 2 channels are above 10000 in event 1726
# 1 channels are above 10000 in event 1727
# 13 channels are above 10000 in event 1731
# 1 channels are above 10000 in event 1733
# 1 channels are above 10000 in event 1737
# 2 channels are above 10000 in event 1741
# 2 channels are above 10000 in event 1742
# 2 channels are above 10000 in event 1744
# 1 channels are above 10000 in event 1745
# 2 channels are above 10000 in event 1746
# 2 channels are above 10000 in event 1748
# 1 channels are above 10000 in event 1750
# 7 channels are above 10000 in event 1751
# 1 channels are above 10000 in event 1752
# 2 channels are above 10000 in event 1753
# 27 channels are above 10000 in event 1754
# 1 channels are above 10000 in event 1762
# 1 channels are above 10000 in event 1763
# 1 channels are above 10000 in event 1764
# 1 channels are above 10000 in event 1766
# 28 channels are above 10000 in event 1769
# 24 channels are above 10000 in event 1770
# 2 channels are above 10000 in event 1772
# 2 channels are above 10000 in event 1773
# 2 channels are above 10000 in event 1776
# 2 channels are above 10000 in event 1777
# 34 channels are above 10000 in event 1779
# 1 channels are above 10000 in event 1780
# 1 channels are above 10000 in event 1781
# 2 channels are above 10000 in event 1782
# 2 channels are above 10000 in event 1783
# 2 channels are above 10000 in event 1784
# 1 channels are above 10000 in event 1786
# 1 channels are above 10000 in event 1787
# 1 channels are above 10000 in event 1789
# 2 channels are above 10000 in event 1790
# 19 channels are above 10000 in event 1791
# 2 channels are above 10000 in event 1792
# 1 channels are above 10000 in event 1793
# 1 channels are above 10000 in event 1796
# 1 channels are above 10000 in event 1798
# 2 channels are above 10000 in event 1799
# 15 channels are above 10000 in event 1801
# 1 channels are above 10000 in event 1804
# 2 channels are above 10000 in event 1806
# 2 channels are above 10000 in event 1807
# 1 channels are above 10000 in event 1808
# 9 channels are above 10000 in event 1809
# 5 channels are above 10000 in event 1810
# 2 channels are above 10000 in event 1811
# 2 channels are above 10000 in event 1812
# 2 channels are above 10000 in event 1813
# 1 channels are above 10000 in event 1815
# 2 channels are above 10000 in event 1817
# 1 channels are above 10000 in event 1818
# 2 channels are above 10000 in event 1819
# 1 channels are above 10000 in event 1820
# 2 channels are above 10000 in event 1822
# 20 channels are above 10000 in event 1823
# 1 channels are above 10000 in event 1824
# 2 channels are above 10000 in event 1827
# 2 channels are above 10000 in event 1828
# 1 channels are above 10000 in event 1833
# 2 channels are above 10000 in event 1834
# 2 channels are above 10000 in event 1835
# 2 channels are above 10000 in event 1836
# 1 channels are above 10000 in event 1837
# 2 channels are above 10000 in event 1839
# 1 channels are above 10000 in event 1840
# 20 channels are above 10000 in event 1841
# 2 channels are above 10000 in event 1843
# 1 channels are above 10000 in event 1844
# 2 channels are above 10000 in event 1845
# 2 channels are above 10000 in event 1846
# 2 channels are above 10000 in event 1847
# 2 channels are above 10000 in event 1850
# 2 channels are above 10000 in event 1851
# 1 channels are above 10000 in event 1852
# 2 channels are above 10000 in event 1855
# 1 channels are above 10000 in event 1856
# 2 channels are above 10000 in event 1858
# 2 channels are above 10000 in event 1859
# 2 channels are above 10000 in event 1860
# 1 channels are above 10000 in event 1861
# 1 channels are above 10000 in event 1863
# 2 channels are above 10000 in event 1864
# 1 channels are above 10000 in event 1865
# 2 channels are above 10000 in event 1868
# 2 channels are above 10000 in event 1869
# 2 channels are above 10000 in event 1872
# 2 channels are above 10000 in event 1873
# 2 channels are above 10000 in event 1879
# 2 channels are above 10000 in event 1880
# 2 channels are above 10000 in event 1883
# 1 channels are above 10000 in event 1884
# 2 channels are above 10000 in event 1885
# 1 channels are above 10000 in event 1892
# 1 channels are above 10000 in event 1894
# 2 channels are above 10000 in event 1898
# 17 channels are above 10000 in event 1899
# 1 channels are above 10000 in event 1900
# 1 channels are above 10000 in event 1901
# 1 channels are above 10000 in event 1905
# 1 channels are above 10000 in event 1906
# 14 channels are above 10000 in event 1907
# 1 channels are above 10000 in event 1909
# 2 channels are above 10000 in event 1911
# 1 channels are above 10000 in event 1912
# 8 channels are above 10000 in event 1914
# 1 channels are above 10000 in event 1915
# 19 channels are above 10000 in event 1918
# 2 channels are above 10000 in event 1919
# 2 channels are above 10000 in event 1920
# 18 channels are above 10000 in event 1921
# 1 channels are above 10000 in event 1923
# 3 channels are above 10000 in event 1927
# 2 channels are above 10000 in event 1928
# 1 channels are above 10000 in event 1929
# 6 channels are above 10000 in event 1930
# 2 channels are above 10000 in event 1932
# 2 channels are above 10000 in event 1933
# 1 channels are above 10000 in event 1935
# 2 channels are above 10000 in event 1940
# 2 channels are above 10000 in event 1941
# 14 channels are above 10000 in event 1942
# 2 channels are above 10000 in event 1944
# 2 channels are above 10000 in event 1946
# 2 channels are above 10000 in event 1947
# 2 channels are above 10000 in event 1948
# 2 channels are above 10000 in event 1949
# 2 channels are above 10000 in event 1950
# 2 channels are above 10000 in event 1951
# 1 channels are above 10000 in event 1952
# 1 channels are above 10000 in event 1954
# 2 channels are above 10000 in event 1955
# 2 channels are above 10000 in event 1956
# 2 channels are above 10000 in event 1958
# 2 channels are above 10000 in event 1960
# 2 channels are above 10000 in event 1961
# 8 channels are above 10000 in event 1962
# 1 channels are above 10000 in event 1963
# 79 channels are above 10000 in event 1964
# 2 channels are above 10000 in event 1965
# 2 channels are above 10000 in event 1966
# 12 channels are above 10000 in event 1968
# 2 channels are above 10000 in event 1971
# 1 channels are above 10000 in event 1973
# 1 channels are above 10000 in event 1974
# 1 channels are above 10000 in event 1975
# ...
# 1 channels are above 10000 in event 4788
# 2 channels are above 10000 in event 4791
# 2 channels are above 10000 in event 4796
# 1 channels are above 10000 in event 4798
# 1 channels are above 10000 in event 4800
# 1 channels are above 10000 in event 4801
# 2 channels are above 10000 in event 4808
# 1 channels are above 10000 in event 4809
# 1 channels are above 10000 in event 4811
# 2 channels are above 10000 in event 4814
# 33 channels are above 10000 in event 4815
# 2 channels are above 10000 in event 4816
# 2 channels are above 10000 in event 4817
# 1 channels are above 10000 in event 4818
# 15 channels are above 10000 in event 4819
# 21 channels are above 10000 in event 4820
# 1 channels are above 10000 in event 4823
# 2 channels are above 10000 in event 4824
# 19 channels are above 10000 in event 4825
# 2 channels are above 10000 in event 4827
# 1 channels are above 10000 in event 4828
# 1 channels are above 10000 in event 4830
# 2 channels are above 10000 in event 4832
# 1 channels are above 10000 in event 4833
# 2 channels are above 10000 in event 4835
# 1 channels are above 10000 in event 4836
# 18 channels are above 10000 in event 4837
# 2 channels are above 10000 in event 4838
# 2 channels are above 10000 in event 4839
# 2 channels are above 10000 in event 4840
# 2 channels are above 10000 in event 4841
# 2 channels are above 10000 in event 4842
# 2 channels are above 10000 in event 4845
# 2 channels are above 10000 in event 4846
# 1 channels are above 10000 in event 4847
# 2 channels are above 10000 in event 4848
# 16 channels are above 10000 in event 4850
# 2 channels are above 10000 in event 4851
# 2 channels are above 10000 in event 4853
# 1 channels are above 10000 in event 4855
# 17 channels are above 10000 in event 4857
# 1 channels are above 10000 in event 4858
# 2 channels are above 10000 in event 4859
# 2 channels are above 10000 in event 4861
# 11 channels are above 10000 in event 4864
# 2 channels are above 10000 in event 4870
# 1 channels are above 10000 in event 4872
# 1 channels are above 10000 in event 4873
# 2 channels are above 10000 in event 4874
# 2 channels are above 10000 in event 4877
# 1 channels are above 10000 in event 4880
# 1 channels are above 10000 in event 4882
# 22 channels are above 10000 in event 4883
# 1 channels are above 10000 in event 4886
# 1 channels are above 10000 in event 4887
# 2 channels are above 10000 in event 4889
# 2 channels are above 10000 in event 4892
# 26 channels are above 10000 in event 4893
# 1 channels are above 10000 in event 4894
# 14 channels are above 10000 in event 4896
# 2 channels are above 10000 in event 4897
# 1 channels are above 10000 in event 4898
# 1 channels are above 10000 in event 4899
# 2 channels are above 10000 in event 4900
# 2 channels are above 10000 in event 4902
# 1 channels are above 10000 in event 4904
# 3 channels are above 10000 in event 4906
# 1 channels are above 10000 in event 4907
# 1 channels are above 10000 in event 4912
# 2 channels are above 10000 in event 4913
# 2 channels are above 10000 in event 4914
# 2 channels are above 10000 in event 4916
# 2 channels are above 10000 in event 4917
# 2 channels are above 10000 in event 4918
# 1 channels are above 10000 in event 4919
# 2 channels are above 10000 in event 4920
# 1 channels are above 10000 in event 4921
# 2 channels are above 10000 in event 4922
# 1 channels are above 10000 in event 4924
# 2 channels are above 10000 in event 4925
# 2 channels are above 10000 in event 4926
# 2 channels are above 10000 in event 4927
# 2 channels are above 10000 in event 4930
# 2 channels are above 10000 in event 4931
# 1 channels are above 10000 in event 4932
# 2 channels are above 10000 in event 4935
# 1 channels are above 10000 in event 4936
# 2 channels are above 10000 in event 4937
# 2 channels are above 10000 in event 4938
# 2 channels are above 10000 in event 4939
# 1 channels are above 10000 in event 4940
# 2 channels are above 10000 in event 4941
# 2 channels are above 10000 in event 4944
# 2 channels are above 10000 in event 4945
# 2 channels are above 10000 in event 4946
# 1 channels are above 10000 in event 4947
# 2 channels are above 10000 in event 4948
# 1 channels are above 10000 in event 4950
# 2 channels are above 10000 in event 4951
# 4 channels are above 10000 in event 4952
# 2 channels are above 10000 in event 4954
# 2 channels are above 10000 in event 4956
# 1 channels are above 10000 in event 4961
# 2 channels are above 10000 in event 4963
# 25 channels are above 10000 in event 4964
# 1 channels are above 10000 in event 4966
# 2 channels are above 10000 in event 4968
# 1 channels are above 10000 in event 4971
# 1 channels are above 10000 in event 4973
# 2 channels are above 10000 in event 4974
# 2 channels are above 10000 in event 4975
# 6 channels are above 10000 in event 4976
# 1 channels are above 10000 in event 4977
# 2 channels are above 10000 in event 4978
# 20 channels are above 10000 in event 4979
# 2 channels are above 10000 in event 4980
# 2 channels are above 10000 in event 4982
# 3 channels are above 10000 in event 4984
# 2 channels are above 10000 in event 4985
# 2 channels are above 10000 in event 4988
# 1 channels are above 10000 in event 4989
# 2 channels are above 10000 in event 4990
# 2 channels are above 10000 in event 4993
# 33 channels are above 10000 in event 4994
# 23 channels are above 10000 in event 4995
# 1 channels are above 10000 in event 4996
# 2 channels are above 10000 in event 4997
# 2 channels are above 10000 in event 5000
# 2 channels are above 10000 in event 5001
# 5 channels are above 10000 in event 5002
# 1 channels are above 10000 in event 5003
# 2 channels are above 10000 in event 5007
# 1 channels are above 10000 in event 5011
# 2 channels are above 10000 in event 5013
# 1 channels are above 10000 in event 5014
# 1 channels are above 10000 in event 5015
# 4 channels are above 10000 in event 5016
# 1 channels are above 10000 in event 5017
# 2 channels are above 10000 in event 5018
# 1 channels are above 10000 in event 5022
# 1 channels are above 10000 in event 5026
# 2 channels are above 10000 in event 5027
# 2 channels are above 10000 in event 5028
# 2 channels are above 10000 in event 5029
# 1 channels are above 10000 in event 5033
# 24 channels are above 10000 in event 5036
# 1 channels are above 10000 in event 5037
# 2 channels are above 10000 in event 5038
# 2 channels are above 10000 in event 5039
# 1 channels are above 10000 in event 5040
# 2 channels are above 10000 in event 5041
# 2 channels are above 10000 in event 5042
# 2 channels are above 10000 in event 5043
# 2 channels are above 10000 in event 5044
# 2 channels are above 10000 in event 5045
# 2 channels are above 10000 in event 5046
# 1 channels are above 10000 in event 5048
# 9 channels are above 10000 in event 5049
# 1 channels are above 10000 in event 5052
# 1 channels are above 10000 in event 5053
# 2 channels are above 10000 in event 5054
# 2 channels are above 10000 in event 5055
# 1 channels are above 10000 in event 5056
# 1 channels are above 10000 in event 5057
# 1 channels are above 10000 in event 5058
# 2 channels are above 10000 in event 5059
# 2 channels are above 10000 in event 5060
# 1 channels are above 10000 in event 5061
# 1 channels are above 10000 in event 5066
# 2 channels are above 10000 in event 5067
# 52 channels are above 10000 in event 5068
# 11 channels are above 10000 in event 5069
# 1 channels are above 10000 in event 5070
# 1 channels are above 10000 in event 5071
# 2 channels are above 10000 in event 5072
# 2 channels are above 10000 in event 5073
# 2 channels are above 10000 in event 5075
# 1 channels are above 10000 in event 5076
# 1 channels are above 10000 in event 5078
# 1 channels are above 10000 in event 5079
# 2 channels are above 10000 in event 5080
# 1 channels are above 10000 in event 5082
# 2 channels are above 10000 in event 5083
# 1 channels are above 10000 in event 5085
# 2 channels are above 10000 in event 5086
# 1 channels are above 10000 in event 5087
# 12 channels are above 10000 in event 5089
# 2 channels are above 10000 in event 5090
# 2 channels are above 10000 in event 5093
# 2 channels are above 10000 in event 5094
# 1 channels are above 10000 in event 5095
# 1 channels are above 10000 in event 5096
# 1 channels are above 10000 in event 5097
# 2 channels are above 10000 in event 5100
# 2 channels are above 10000 in event 5103
# 2 channels are above 10000 in event 5105
# 2 channels are above 10000 in event 5106
# 1 channels are above 10000 in event 5108
# 2 channels are above 10000 in event 5109
# 2 channels are above 10000 in event 5110
# 1 channels are above 10000 in event 5111
# 1 channels are above 10000 in event 5112
# 1 channels are above 10000 in event 5113
# 2 channels are above 10000 in event 5114
# 10 channels are above 10000 in event 5118
# 1 channels are above 10000 in event 5121
# 6 channels are above 10000 in event 5122
# 3 channels are above 10000 in event 5125
# 2 channels are above 10000 in event 5127
# 2 channels are above 10000 in event 5128
# 2 channels are above 10000 in event 5130
# 2 channels are above 10000 in event 5131
# 2 channels are above 10000 in event 5132
# 9 channels are above 10000 in event 5133
# 1 channels are above 10000 in event 5134
# 16 channels are above 10000 in event 5135
# 1 channels are above 10000 in event 5137
# 1 channels are above 10000 in event 5138
# 1 channels are above 10000 in event 5141
# 17 channels are above 10000 in event 5143
# 29 channels are above 10000 in event 5145
# 1 channels are above 10000 in event 5146
# 2 channels are above 10000 in event 5148
# 37 channels are above 10000 in event 5149
# 2 channels are above 10000 in event 5150
# 4 channels are above 10000 in event 5153
# 2 channels are above 10000 in event 5156
# 1 channels are above 10000 in event 5157
# 2 channels are above 10000 in event 5158
# 2 channels are above 10000 in event 5159
# 1 channels are above 10000 in event 5160
# 1 channels are above 10000 in event 5161
# 2 channels are above 10000 in event 5162
# 22 channels are above 10000 in event 5163
# 2 channels are above 10000 in event 5164
# 2 channels are above 10000 in event 5166
# 2 channels are above 10000 in event 5167
# 2 channels are above 10000 in event 5168
# 1 channels are above 10000 in event 5169
# 1 channels are above 10000 in event 5170
# 22 channels are above 10000 in event 5171
# 1 channels are above 10000 in event 5172
# 2 channels are above 10000 in event 5173
# 2 channels are above 10000 in event 5175
# 2 channels are above 10000 in event 5176
# 1 channels are above 10000 in event 5177
# 1 channels are above 10000 in event 5179
# 1 channels are above 10000 in event 5180
# 2 channels are above 10000 in event 5181
# 2 channels are above 10000 in event 5183
# 1 channels are above 10000 in event 5184
# 2 channels are above 10000 in event 5185
# 9 channels are above 10000 in event 5188
# 1 channels are above 10000 in event 5190
# 2 channels are above 10000 in event 5193
# 2 channels are above 10000 in event 5195
# 2 channels are above 10000 in event 5197
# 1 channels are above 10000 in event 5198
# 17 channels are above 10000 in event 5199
# 2 channels are above 10000 in event 5201
# 1 channels are above 10000 in event 5204
# 2 channels are above 10000 in event 5207
# 2 channels are above 10000 in event 5209
# 1 channels are above 10000 in event 5211
# 1 channels are above 10000 in event 5212
# 7 channels are above 10000 in event 5213
# 2 channels are above 10000 in event 5214
# 2 channels are above 10000 in event 5215
# 2 channels are above 10000 in event 5217
# 2 channels are above 10000 in event 5219
# 2 channels are above 10000 in event 5221
# 2 channels are above 10000 in event 5223
# 14 channels are above 10000 in event 5224
# 2 channels are above 10000 in event 5227
# 1 channels are above 10000 in event 5229
# 2 channels are above 10000 in event 5230
# 18 channels are above 10000 in event 5232
# 1 channels are above 10000 in event 5234
# 6 channels are above 10000 in event 5235
# 1 channels are above 10000 in event 5239
# 4 channels are above 10000 in event 5242
# 2 channels are above 10000 in event 5244
# 1 channels are above 10000 in event 5246
# 2 channels are above 10000 in event 5247
# 1 channels are above 10000 in event 5251
# 2 channels are above 10000 in event 5252
# 1 channels are above 10000 in event 5256
# 2 channels are above 10000 in event 5257
# 2 channels are above 10000 in event 5258
# 2 channels are above 10000 in event 5262
# 2 channels are above 10000 in event 5264
# 1 channels are above 10000 in event 5265
# 1 channels are above 10000 in event 5267
# 2 channels are above 10000 in event 5272
# 1 channels are above 10000 in event 5276
# 35 channels are above 10000 in event 5278
# 2 channels are above 10000 in event 5287
# 2 channels are above 10000 in event 5288
# 3 channels are above 10000 in event 5289
# 1 channels are above 10000 in event 5290
# 15 channels are above 10000 in event 5292
# 2 channels are above 10000 in event 5293
# 2 channels are above 10000 in event 5297
# 1 channels are above 10000 in event 5299
# 1 channels are above 10000 in event 5301
# 2 channels are above 10000 in event 5302
# 2 channels are above 10000 in event 5303
# 2 channels are above 10000 in event 5306
# 2 channels are above 10000 in event 5307
# 1 channels are above 10000 in event 5310
# 2 channels are above 10000 in event 5311
# 1 channels are above 10000 in event 5313
# 2 channels are above 10000 in event 5314
# 2 channels are above 10000 in event 5315
# 2 channels are above 10000 in event 5317
# 1 channels are above 10000 in event 5320
# 2 channels are above 10000 in event 5322
# 12 channels are above 10000 in event 5323
# 2 channels are above 10000 in event 5324
# 2 channels are above 10000 in event 5327
# 17 channels are above 10000 in event 5328
# 1 channels are above 10000 in event 5330
# 2 channels are above 10000 in event 5331
# 1 channels are above 10000 in event 5333
# 2 channels are above 10000 in event 5335
# 11 channels are above 10000 in event 5336
# 1 channels are above 10000 in event 5337
# 2 channels are above 10000 in event 5341
# 2 channels are above 10000 in event 5343
# 1 channels are above 10000 in event 5344
# 2 channels are above 10000 in event 5347
# 2 channels are above 10000 in event 5348
# 38 channels are above 10000 in event 5349
# 2 channels are above 10000 in event 5350
# 21 channels are above 10000 in event 5351
# 15 channels are above 10000 in event 5352
# 1 channels are above 10000 in event 5354
# 2 channels are above 10000 in event 5356
# 2 channels are above 10000 in event 5357
# 1 channels are above 10000 in event 5359
# 8 channels are above 10000 in event 5360
# 2 channels are above 10000 in event 5361
# 12 channels are above 10000 in event 5362
# 1 channels are above 10000 in event 5364
# 1 channels are above 10000 in event 5368
# 2 channels are above 10000 in event 5369
# 2 channels are above 10000 in event 5370
# 2 channels are above 10000 in event 5371
# 1 channels are above 10000 in event 5372
# 2 channels are above 10000 in event 5374
# 2 channels are above 10000 in event 5376
# 2 channels are above 10000 in event 5380
# 1 channels are above 10000 in event 5381
# 2 channels are above 10000 in event 5382
# 5 channels are above 10000 in event 5383
# 1 channels are above 10000 in event 5384
# 2 channels are above 10000 in event 5386
# 2 channels are above 10000 in event 5387
# 2 channels are above 10000 in event 5388
# 3 channels are above 10000 in event 5389
# 2 channels are above 10000 in event 5391
# 2 channels are above 10000 in event 5393
# 1 channels are above 10000 in event 5396
# 1 channels are above 10000 in event 5398
# 2 channels are above 10000 in event 5399
# 2 channels are above 10000 in event 5403
# 2 channels are above 10000 in event 5404
# 2 channels are above 10000 in event 5406
# 2 channels are above 10000 in event 5408
# 1 channels are above 10000 in event 5409
# 2 channels are above 10000 in event 5410
# 2 channels are above 10000 in event 5411
# 2 channels are above 10000 in event 5412
# 1 channels are above 10000 in event 5413
# 2 channels are above 10000 in event 5415
# 2 channels are above 10000 in event 5417
# 1 channels are above 10000 in event 5418
# 1 channels are above 10000 in event 5419
# 1 channels are above 10000 in event 5420
# 1 channels are above 10000 in event 5423
# 1 channels are above 10000 in event 5424
# 1 channels are above 10000 in event 5425
# 2 channels are above 10000 in event 5426
# 1 channels are above 10000 in event 5427
# 1 channels are above 10000 in event 5428
# 6 channels are above 10000 in event 5429
# 2 channels are above 10000 in event 5431
# 3274 out of 5433 events have at least one waveform that goes above 10000

# %%
# for one event plot all waveforms
colors = ['r', 'b', 'c', 'm', 'y', 'g', 'k', 'orange']
event = 58
light = thd_correct(file['light/wvfm/data']['samples'])
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
for i in range(8):
    for j in range(64):
        ax.plot(light[event][i,j], c='grey', alpha=0.1)
        if np.max(light[event][i,j]) > 10000:
            ax.plot(light[event][i,j], c=colors[i], alpha=0.3, label=f'channel {(i,j)}')
plt.xlabel('ticks [16 ns]')
plt.ylabel('ADC counts')
plt.legend()
plt.title('Event ' + str(event) + ' waveforms, all channels')
plt.show()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# now lets do this for some files
path = '/global/cfs/cdirs/dune/users/lmlepin/2x2_neutron_prod/PNS_prod_V1/FLOW/'
filename = '2x2_MyQGSP_BERT_ArHP_DTG_PNS_prod_V1_{num}.FLOW.hdf5'

for i in range(0, 20):
    print('file', i)
    file = h5flow.data.H5FlowDataManager(path + filename.format(num=i), "r")
    try:
        a = file["light/wvfm/data"]['samples']
        a = thd_correct(a)
        threshold = 1000
        n = 0
        summary = {}
        for i in range(len(a)):
            if np.max(a[i]) > threshold:
                n += 1
                # count how many channels are above threshold
                l = 0
                for j in range(8):
                    for k in range(64):
                        if np.max(a[i][j,k]) > threshold:
                            l += 1
                print(l, 'channels are above', threshold, 'in event', i)
                summary[i] = l
        print(n, 'out of', len(file['light/wvfm/data']), 'events have at least one waveform that goes above', threshold)
        print('')
    except:
        print('no data')
        print('')
# Out:
# file 0
# 13 channels are above 1000 in event 0
# 16 channels are above 1000 in event 10
# 12 channels are above 1000 in event 11
# 7 channels are above 1000 in event 12
# 7 channels are above 1000 in event 13
# 5 channels are above 1000 in event 14
# 2 channels are above 1000 in event 16
# 6 channels are above 1000 in event 17
# 4 channels are above 1000 in event 18
# 4 channels are above 1000 in event 21
# 4 channels are above 1000 in event 22
# 1 channels are above 1000 in event 24
# 1 channels are above 1000 in event 26
# 3 channels are above 1000 in event 27
# 4 channels are above 1000 in event 28
# 6 channels are above 1000 in event 29
# 1 channels are above 1000 in event 30
# 3 channels are above 1000 in event 31
# 4 channels are above 1000 in event 32
# 16 channels are above 1000 in event 33
# 1 channels are above 1000 in event 35
# 29 channels are above 1000 in event 40
# 20 channels are above 1000 in event 45
# 1 channels are above 1000 in event 48
# 12 channels are above 1000 in event 49
# 2 channels are above 1000 in event 53
# 5 channels are above 1000 in event 54
# 7 channels are above 1000 in event 57
# 1 channels are above 1000 in event 59
# 1 channels are above 1000 in event 60
# 8 channels are above 1000 in event 61
# 7 channels are above 1000 in event 65
# 2 channels are above 1000 in event 67
# 9 channels are above 1000 in event 68
# 4 channels are above 1000 in event 69
# 15 channels are above 1000 in event 71
# 1 channels are above 1000 in event 72
# 7 channels are above 1000 in event 73
# 4 channels are above 1000 in event 74
# 14 channels are above 1000 in event 78
# 14 channels are above 1000 in event 82
# 20 channels are above 1000 in event 85
# 4 channels are above 1000 in event 86
# 5 channels are above 1000 in event 91
# 16 channels are above 1000 in event 93
# 1 channels are above 1000 in event 98
# 3 channels are above 1000 in event 99
# 5 channels are above 1000 in event 101
# 5 channels are above 1000 in event 102
# 2 channels are above 1000 in event 104
# 9 channels are above 1000 in event 106
# 51 out of 108 events have at least one waveform that goes above 1000
#
# file 1
# 1 channels are above 1000 in event 0
# 11 channels are above 1000 in event 2
# 8 channels are above 1000 in event 6
# 4 channels are above 1000 in event 7
# 1 channels are above 1000 in event 8
# 2 channels are above 1000 in event 11
# 3 channels are above 1000 in event 12
# 19 channels are above 1000 in event 14
# 1 channels are above 1000 in event 15
# 22 channels are above 1000 in event 18
# 10 channels are above 1000 in event 21
# 7 channels are above 1000 in event 26
# 28 channels are above 1000 in event 28
# 2 channels are above 1000 in event 29
# 32 channels are above 1000 in event 30
# 3 channels are above 1000 in event 33
# 14 channels are above 1000 in event 36
# 17 channels are above 1000 in event 37
# 3 channels are above 1000 in event 41
# 7 channels are above 1000 in event 42
# 3 channels are above 1000 in event 44
# 6 channels are above 1000 in event 46
# 2 channels are above 1000 in event 49
# 7 channels are above 1000 in event 50
# 3 channels are above 1000 in event 51
# 1 channels are above 1000 in event 53
# 2 channels are above 1000 in event 55
# 4 channels are above 1000 in event 56
# 6 channels are above 1000 in event 57
# 7 channels are above 1000 in event 60
# 15 channels are above 1000 in event 61
# 6 channels are above 1000 in event 62
# 3 channels are above 1000 in event 63
# 6 channels are above 1000 in event 66
# 8 channels are above 1000 in event 68
# 11 channels are above 1000 in event 69
# 2 channels are above 1000 in event 70
# 1 channels are above 1000 in event 72
# 2 channels are above 1000 in event 74
# 2 channels are above 1000 in event 75
# 1 channels are above 1000 in event 76
# 6 channels are above 1000 in event 77
# 9 channels are above 1000 in event 82
# 2 channels are above 1000 in event 83
# 2 channels are above 1000 in event 84
# 12 channels are above 1000 in event 87
# 3 channels are above 1000 in event 88
# 2 channels are above 1000 in event 90
# 1 channels are above 1000 in event 91
# 4 channels are above 1000 in event 93
# 14 channels are above 1000 in event 95
# 4 channels are above 1000 in event 97
# 52 out of 99 events have at least one waveform that goes above 1000
#
# file 2
# 18 channels are above 1000 in event 1
# 8 channels are above 1000 in event 2
# 5 channels are above 1000 in event 3
# 4 channels are above 1000 in event 4
# 9 channels are above 1000 in event 5
# 5 channels are above 1000 in event 6
# 18 channels are above 1000 in event 8
# 4 channels are above 1000 in event 10
# 2 channels are above 1000 in event 13
# 1 channels are above 1000 in event 17
# 2 channels are above 1000 in event 19
# 20 channels are above 1000 in event 20
# 7 channels are above 1000 in event 21
# 15 channels are above 1000 in event 22
# 2 channels are above 1000 in event 26
# 1 channels are above 1000 in event 28
# 15 channels are above 1000 in event 29
# 9 channels are above 1000 in event 32
# 27 channels are above 1000 in event 34
# 20 channels are above 1000 in event 37
# 4 channels are above 1000 in event 38
# 1 channels are above 1000 in event 39
# 5 channels are above 1000 in event 43
# 4 channels are above 1000 in event 44
# 20 channels are above 1000 in event 46
# 2 channels are above 1000 in event 50
# 6 channels are above 1000 in event 51
# 7 channels are above 1000 in event 52
# 8 channels are above 1000 in event 53
# 15 channels are above 1000 in event 55
# 5 channels are above 1000 in event 56
# 4 channels are above 1000 in event 59
# 1 channels are above 1000 in event 62
# 3 channels are above 1000 in event 67
# 17 channels are above 1000 in event 70
# 10 channels are above 1000 in event 75
# 7 channels are above 1000 in event 78
# 11 channels are above 1000 in event 81
# 3 channels are above 1000 in event 82
# 10 channels are above 1000 in event 83
# 8 channels are above 1000 in event 85
# 1 channels are above 1000 in event 87
# 2 channels are above 1000 in event 89
# 7 channels are above 1000 in event 92
# 2 channels are above 1000 in event 93
# 4 channels are above 1000 in event 95
# 2 channels are above 1000 in event 96
# 47 out of 100 events have at least one waveform that goes above 1000
#
# file 3
# 6 channels are above 1000 in event 3
# 9 channels are above 1000 in event 4
# 25 channels are above 1000 in event 7
# 1 channels are above 1000 in event 8
# 9 channels are above 1000 in event 12
# 24 channels are above 1000 in event 13
# 7 channels are above 1000 in event 14
# 6 channels are above 1000 in event 16
# 8 channels are above 1000 in event 17
# 5 channels are above 1000 in event 19
# 4 channels are above 1000 in event 23
# 6 channels are above 1000 in event 25
# 8 channels are above 1000 in event 26
# 7 channels are above 1000 in event 27
# 5 channels are above 1000 in event 29
# 26 channels are above 1000 in event 30
# 6 channels are above 1000 in event 32
# 5 channels are above 1000 in event 35
# 12 channels are above 1000 in event 36
# 2 channels are above 1000 in event 38
# 4 channels are above 1000 in event 39
# 2 channels are above 1000 in event 42
# 3 channels are above 1000 in event 45
# 22 channels are above 1000 in event 47
# 2 channels are above 1000 in event 49
# 3 channels are above 1000 in event 50
# 1 channels are above 1000 in event 51
# 15 channels are above 1000 in event 53
# 2 channels are above 1000 in event 55
# 1 channels are above 1000 in event 56
# 3 channels are above 1000 in event 58
# 7 channels are above 1000 in event 61
# 6 channels are above 1000 in event 63
# 15 channels are above 1000 in event 66
# 4 channels are above 1000 in event 67
# 2 channels are above 1000 in event 70
# 2 channels are above 1000 in event 72
# 14 channels are above 1000 in event 76
# 7 channels are above 1000 in event 79
# 1 channels are above 1000 in event 83
# 2 channels are above 1000 in event 86
# 7 channels are above 1000 in event 87
# 1 channels are above 1000 in event 88
# 5 channels are above 1000 in event 89
# 14 channels are above 1000 in event 90
# 2 channels are above 1000 in event 92
# 10 channels are above 1000 in event 94
# 4 channels are above 1000 in event 95
# 15 channels are above 1000 in event 97
# 16 channels are above 1000 in event 98
# 30 channels are above 1000 in event 101
# 51 out of 102 events have at least one waveform that goes above 1000
#
# file 4
# 2 channels are above 1000 in event 0
# 22 channels are above 1000 in event 2
# 5 channels are above 1000 in event 4
# 18 channels are above 1000 in event 5
# 10 channels are above 1000 in event 6
# 5 channels are above 1000 in event 8
# 13 channels are above 1000 in event 9
# 13 channels are above 1000 in event 11
# 15 channels are above 1000 in event 12
# 5 channels are above 1000 in event 16
# 6 channels are above 1000 in event 18
# 3 channels are above 1000 in event 19
# 1 channels are above 1000 in event 20
# 4 channels are above 1000 in event 22
# 7 channels are above 1000 in event 23
# 2 channels are above 1000 in event 26
# 11 channels are above 1000 in event 27
# 3 channels are above 1000 in event 29
# 1 channels are above 1000 in event 32
# 7 channels are above 1000 in event 33
# 3 channels are above 1000 in event 35
# 5 channels are above 1000 in event 36
# 14 channels are above 1000 in event 38
# 1 channels are above 1000 in event 39
# 5 channels are above 1000 in event 42
# 11 channels are above 1000 in event 44
# 4 channels are above 1000 in event 48
# 8 channels are above 1000 in event 49
# 4 channels are above 1000 in event 51
# 5 channels are above 1000 in event 57
# 2 channels are above 1000 in event 58
# 9 channels are above 1000 in event 63
# 6 channels are above 1000 in event 66
# 4 channels are above 1000 in event 68
# 1 channels are above 1000 in event 69
# 13 channels are above 1000 in event 70
# 7 channels are above 1000 in event 71
# 15 channels are above 1000 in event 73
# 1 channels are above 1000 in event 74
# 1 channels are above 1000 in event 75
# 2 channels are above 1000 in event 77
# 6 channels are above 1000 in event 79
# 23 channels are above 1000 in event 80
# 9 channels are above 1000 in event 81
# 5 channels are above 1000 in event 84
# 6 channels are above 1000 in event 85
# 22 channels are above 1000 in event 87
# 5 channels are above 1000 in event 88
# 11 channels are above 1000 in event 89
# 26 channels are above 1000 in event 91
# 31 channels are above 1000 in event 92
# 17 channels are above 1000 in event 94
# 4 channels are above 1000 in event 95
# 53 out of 96 events have at least one waveform that goes above 1000
#
# file 5
# 10 channels are above 1000 in event 1
# 2 channels are above 1000 in event 3
# 3 channels are above 1000 in event 4
# 8 channels are above 1000 in event 5
# 1 channels are above 1000 in event 7
# 4 channels are above 1000 in event 8
# 3 channels are above 1000 in event 12
# 6 channels are above 1000 in event 19
# 3 channels are above 1000 in event 25
# 2 channels are above 1000 in event 26
# 6 channels are above 1000 in event 27
# 1 channels are above 1000 in event 28
# 2 channels are above 1000 in event 29
# 2 channels are above 1000 in event 31
# 4 channels are above 1000 in event 32
# 8 channels are above 1000 in event 33
# 15 channels are above 1000 in event 34
# 11 channels are above 1000 in event 37
# 14 channels are above 1000 in event 39
# 9 channels are above 1000 in event 41
# 9 channels are above 1000 in event 42
# 8 channels are above 1000 in event 44
# 15 channels are above 1000 in event 46
# 1 channels are above 1000 in event 47
# 4 channels are above 1000 in event 50
# 3 channels are above 1000 in event 51
# 1 channels are above 1000 in event 52
# 24 channels are above 1000 in event 53
# 2 channels are above 1000 in event 55
# 7 channels are above 1000 in event 58
# 11 channels are above 1000 in event 59
# 11 channels are above 1000 in event 60
# 1 channels are above 1000 in event 61
# 1 channels are above 1000 in event 63
# 6 channels are above 1000 in event 67
# 3 channels are above 1000 in event 68
# 2 channels are above 1000 in event 70
# 4 channels are above 1000 in event 71
# 7 channels are above 1000 in event 72
# 4 channels are above 1000 in event 77
# 7 channels are above 1000 in event 78
# 6 channels are above 1000 in event 79
# 20 channels are above 1000 in event 80
# 14 channels are above 1000 in event 87
# 2 channels are above 1000 in event 88
# 21 channels are above 1000 in event 90
# 8 channels are above 1000 in event 91
# 5 channels are above 1000 in event 92
# 23 channels are above 1000 in event 93
# 14 channels are above 1000 in event 95
# 4 channels are above 1000 in event 96
# 9 channels are above 1000 in event 97
# 9 channels are above 1000 in event 98
# 53 out of 101 events have at least one waveform that goes above 1000
#
# file 6
# 9 channels are above 1000 in event 0
# 4 channels are above 1000 in event 1
# 1 channels are above 1000 in event 4
# 1 channels are above 1000 in event 5
# 5 channels are above 1000 in event 8
# 8 channels are above 1000 in event 10
# 3 channels are above 1000 in event 12
# 15 channels are above 1000 in event 14
# 2 channels are above 1000 in event 18
# 2 channels are above 1000 in event 22
# 1 channels are above 1000 in event 25
# 1 channels are above 1000 in event 28
# 2 channels are above 1000 in event 32
# 8 channels are above 1000 in event 36
# 5 channels are above 1000 in event 37
# 7 channels are above 1000 in event 38
# 11 channels are above 1000 in event 40
# 1 channels are above 1000 in event 41
# 5 channels are above 1000 in event 43
# 6 channels are above 1000 in event 44
# 4 channels are above 1000 in event 46
# 11 channels are above 1000 in event 47
# 9 channels are above 1000 in event 48
# 4 channels are above 1000 in event 49
# 5 channels are above 1000 in event 51
# 19 channels are above 1000 in event 52
# 9 channels are above 1000 in event 53
# 2 channels are above 1000 in event 54
# 3 channels are above 1000 in event 57
# 6 channels are above 1000 in event 58
# 6 channels are above 1000 in event 60
# 8 channels are above 1000 in event 61
# 1 channels are above 1000 in event 64
# 1 channels are above 1000 in event 66
# 9 channels are above 1000 in event 68
# 1 channels are above 1000 in event 70
# 2 channels are above 1000 in event 71
# 2 channels are above 1000 in event 72
# 9 channels are above 1000 in event 73
# 7 channels are above 1000 in event 76
# 4 channels are above 1000 in event 79
# 11 channels are above 1000 in event 80
# 15 channels are above 1000 in event 82
# 7 channels are above 1000 in event 83
# 3 channels are above 1000 in event 87
# 9 channels are above 1000 in event 89
# 4 channels are above 1000 in event 90
# 4 channels are above 1000 in event 93
# 4 channels are above 1000 in event 96
# 13 channels are above 1000 in event 97
# 13 channels are above 1000 in event 100
# 4 channels are above 1000 in event 101
# 52 out of 102 events have at least one waveform that goes above 1000
#
# file 7
# 1 channels are above 1000 in event 0
# 15 channels are above 1000 in event 4
# 16 channels are above 1000 in event 5
# 5 channels are above 1000 in event 7
# 4 channels are above 1000 in event 8
# 2 channels are above 1000 in event 9
# 3 channels are above 1000 in event 10
# 3 channels are above 1000 in event 12
# 4 channels are above 1000 in event 14
# 1 channels are above 1000 in event 16
# 16 channels are above 1000 in event 18
# 1 channels are above 1000 in event 19
# 1 channels are above 1000 in event 20
# 2 channels are above 1000 in event 21
# 4 channels are above 1000 in event 23
# 12 channels are above 1000 in event 27
# 10 channels are above 1000 in event 29
# 2 channels are above 1000 in event 30
# 5 channels are above 1000 in event 32
# 4 channels are above 1000 in event 36
# 7 channels are above 1000 in event 40
# 12 channels are above 1000 in event 43
# 1 channels are above 1000 in event 48
# 9 channels are above 1000 in event 49
# 1 channels are above 1000 in event 51
# 1 channels are above 1000 in event 54
# 2 channels are above 1000 in event 58
# 1 channels are above 1000 in event 59
# 5 channels are above 1000 in event 62
# 8 channels are above 1000 in event 65
# 22 channels are above 1000 in event 67
# 3 channels are above 1000 in event 74
# 2 channels are above 1000 in event 77
# 7 channels are above 1000 in event 78
# 1 channels are above 1000 in event 80
# 3 channels are above 1000 in event 83
# 1 channels are above 1000 in event 87
# 4 channels are above 1000 in event 91
# 15 channels are above 1000 in event 95
# 39 out of 99 events have at least one waveform that goes above 1000
#
# file 8
# 1 channels are above 1000 in event 1
# 2 channels are above 1000 in event 2
# 1 channels are above 1000 in event 4
# 11 channels are above 1000 in event 6
# 2 channels are above 1000 in event 10
# 2 channels are above 1000 in event 11
# 13 channels are above 1000 in event 12
# 4 channels are above 1000 in event 13
# 5 channels are above 1000 in event 18
# 30 channels are above 1000 in event 20
# 15 channels are above 1000 in event 23
# 4 channels are above 1000 in event 24
# 17 channels are above 1000 in event 26
# 1 channels are above 1000 in event 27
# 4 channels are above 1000 in event 28
# 1 channels are above 1000 in event 31
# 11 channels are above 1000 in event 33
# 21 channels are above 1000 in event 36
# 1 channels are above 1000 in event 44
# 10 channels are above 1000 in event 45
# 8 channels are above 1000 in event 47
# 5 channels are above 1000 in event 48
# 4 channels are above 1000 in event 49
# 1 channels are above 1000 in event 51
# 9 channels are above 1000 in event 52
# 3 channels are above 1000 in event 57
# 8 channels are above 1000 in event 59
# 15 channels are above 1000 in event 62
# 3 channels are above 1000 in event 63
# 5 channels are above 1000 in event 64
# 4 channels are above 1000 in event 68
# 10 channels are above 1000 in event 69
# 3 channels are above 1000 in event 70
# 7 channels are above 1000 in event 72
# 1 channels are above 1000 in event 73
# 8 channels are above 1000 in event 75
# 5 channels are above 1000 in event 78
# 14 channels are above 1000 in event 79
# 3 channels are above 1000 in event 81
# 7 channels are above 1000 in event 86
# 8 channels are above 1000 in event 87
# 2 channels are above 1000 in event 89
# 6 channels are above 1000 in event 90
# 4 channels are above 1000 in event 94
# 3 channels are above 1000 in event 95
# 4 channels are above 1000 in event 97
# 1 channels are above 1000 in event 98
# 47 out of 100 events have at least one waveform that goes above 1000
#
# file 9
# 8 channels are above 1000 in event 5
# 25 channels are above 1000 in event 6
# 1 channels are above 1000 in event 7
# 5 channels are above 1000 in event 9
# 2 channels are above 1000 in event 12
# 5 channels are above 1000 in event 15
# 1 channels are above 1000 in event 16
# 5 channels are above 1000 in event 17
# 7 channels are above 1000 in event 22
# 1 channels are above 1000 in event 23
# 13 channels are above 1000 in event 25
# 13 channels are above 1000 in event 26
# 9 channels are above 1000 in event 27
# 1 channels are above 1000 in event 28
# 6 channels are above 1000 in event 30
# 15 channels are above 1000 in event 31
# 6 channels are above 1000 in event 35
# 5 channels are above 1000 in event 36
# 6 channels are above 1000 in event 38
# 1 channels are above 1000 in event 40
# 1 channels are above 1000 in event 44
# 3 channels are above 1000 in event 45
# 1 channels are above 1000 in event 47
# 20 channels are above 1000 in event 48
# 3 channels are above 1000 in event 49
# 1 channels are above 1000 in event 50
# 3 channels are above 1000 in event 51
# 5 channels are above 1000 in event 53
# 9 channels are above 1000 in event 55
# 5 channels are above 1000 in event 56
# 4 channels are above 1000 in event 61
# 11 channels are above 1000 in event 62
# 6 channels are above 1000 in event 64
# 10 channels are above 1000 in event 65
# 12 channels are above 1000 in event 68
# 2 channels are above 1000 in event 69
# 7 channels are above 1000 in event 75
# 25 channels are above 1000 in event 76
# 31 channels are above 1000 in event 77
# 7 channels are above 1000 in event 80
# 9 channels are above 1000 in event 81
# 6 channels are above 1000 in event 83
# 15 channels are above 1000 in event 85
# 4 channels are above 1000 in event 87
# 10 channels are above 1000 in event 92
# 45 out of 95 events have at least one waveform that goes above 1000
#
# file 10
# no data
#
# file 11
# 2 channels are above 1000 in event 1
# 7 channels are above 1000 in event 4
# 14 channels are above 1000 in event 9
# 6 channels are above 1000 in event 10
# 2 channels are above 1000 in event 11
# 10 channels are above 1000 in event 12
# 3 channels are above 1000 in event 13
# 18 channels are above 1000 in event 14
# 13 channels are above 1000 in event 15
# 3 channels are above 1000 in event 16
# 1 channels are above 1000 in event 19
# 5 channels are above 1000 in event 20
# 4 channels are above 1000 in event 21
# 6 channels are above 1000 in event 22
# 3 channels are above 1000 in event 23
# 1 channels are above 1000 in event 27
# 5 channels are above 1000 in event 29
# 4 channels are above 1000 in event 31
# 3 channels are above 1000 in event 34
# 3 channels are above 1000 in event 35
# 6 channels are above 1000 in event 36
# 7 channels are above 1000 in event 38
# 42 channels are above 1000 in event 39
# 7 channels are above 1000 in event 40
# 10 channels are above 1000 in event 41
# 8 channels are above 1000 in event 43
# 1 channels are above 1000 in event 45
# 3 channels are above 1000 in event 49
# 1 channels are above 1000 in event 50
# 7 channels are above 1000 in event 53
# 1 channels are above 1000 in event 56
# 9 channels are above 1000 in event 57
# 2 channels are above 1000 in event 58
# 1 channels are above 1000 in event 59
# 2 channels are above 1000 in event 69
# 1 channels are above 1000 in event 70
# 1 channels are above 1000 in event 71
# 4 channels are above 1000 in event 74
# 16 channels are above 1000 in event 78
# 1 channels are above 1000 in event 80
# 5 channels are above 1000 in event 83
# 11 channels are above 1000 in event 85
# 4 channels are above 1000 in event 86
# 9 channels are above 1000 in event 87
# 5 channels are above 1000 in event 88
# 1 channels are above 1000 in event 92
# 5 channels are above 1000 in event 93
# 2 channels are above 1000 in event 94
# 8 channels are above 1000 in event 95
# 17 channels are above 1000 in event 96
# 25 channels are above 1000 in event 98
# 2 channels are above 1000 in event 99
# 52 out of 100 events have at least one waveform that goes above 1000
#
# file 12
# 2 channels are above 1000 in event 2
# 6 channels are above 1000 in event 4
# 5 channels are above 1000 in event 8
# 1 channels are above 1000 in event 9
# 1 channels are above 1000 in event 10
# 2 channels are above 1000 in event 11
# 1 channels are above 1000 in event 12
# 4 channels are above 1000 in event 13
# 9 channels are above 1000 in event 14
# 1 channels are above 1000 in event 15
# 3 channels are above 1000 in event 16
# 2 channels are above 1000 in event 18
# 8 channels are above 1000 in event 20
# 15 channels are above 1000 in event 22
# 11 channels are above 1000 in event 24
# 2 channels are above 1000 in event 25
# 4 channels are above 1000 in event 27
# 4 channels are above 1000 in event 28
# 8 channels are above 1000 in event 33
# 6 channels are above 1000 in event 34
# 2 channels are above 1000 in event 37
# 1 channels are above 1000 in event 38
# 4 channels are above 1000 in event 39
# 14 channels are above 1000 in event 40
# 4 channels are above 1000 in event 41
# 3 channels are above 1000 in event 42
# 9 channels are above 1000 in event 43
# 11 channels are above 1000 in event 45
# 1 channels are above 1000 in event 46
# 11 channels are above 1000 in event 51
# 8 channels are above 1000 in event 54
# 2 channels are above 1000 in event 55
# 3 channels are above 1000 in event 58
# 18 channels are above 1000 in event 63
# 1 channels are above 1000 in event 64
# 16 channels are above 1000 in event 69
# 8 channels are above 1000 in event 70
# 6 channels are above 1000 in event 73
# 4 channels are above 1000 in event 81
# 7 channels are above 1000 in event 83
# 2 channels are above 1000 in event 85
# 1 channels are above 1000 in event 86
# 1 channels are above 1000 in event 87
# 14 channels are above 1000 in event 88
# 1 channels are above 1000 in event 95
# 4 channels are above 1000 in event 98
# 6 channels are above 1000 in event 101
# 5 channels are above 1000 in event 103
# 48 out of 104 events have at least one waveform that goes above 1000
#
# file 13
# 11 channels are above 1000 in event 0
# 6 channels are above 1000 in event 1
# 3 channels are above 1000 in event 3
# 3 channels are above 1000 in event 5
# 9 channels are above 1000 in event 6
# 21 channels are above 1000 in event 10
# 15 channels are above 1000 in event 11
# 2 channels are above 1000 in event 14
# 3 channels are above 1000 in event 19
# 14 channels are above 1000 in event 20
# 1 channels are above 1000 in event 24
# 7 channels are above 1000 in event 25
# 3 channels are above 1000 in event 26
# 2 channels are above 1000 in event 27
# 1 channels are above 1000 in event 31
# 8 channels are above 1000 in event 32
# 22 channels are above 1000 in event 33
# 26 channels are above 1000 in event 37
# 1 channels are above 1000 in event 39
# 1 channels are above 1000 in event 40
# 2 channels are above 1000 in event 41
# 4 channels are above 1000 in event 43
# 8 channels are above 1000 in event 44
# 5 channels are above 1000 in event 47
# 5 channels are above 1000 in event 48
# 4 channels are above 1000 in event 49
# 7 channels are above 1000 in event 50
# 2 channels are above 1000 in event 52
# 1 channels are above 1000 in event 53
# 11 channels are above 1000 in event 56
# 2 channels are above 1000 in event 57
# 2 channels are above 1000 in event 60
# 9 channels are above 1000 in event 62
# 1 channels are above 1000 in event 66
# 13 channels are above 1000 in event 68
# 1 channels are above 1000 in event 69
# 5 channels are above 1000 in event 71
# 28 channels are above 1000 in event 75
# 8 channels are above 1000 in event 76
# 3 channels are above 1000 in event 77
# 8 channels are above 1000 in event 80
# 5 channels are above 1000 in event 81
# 8 channels are above 1000 in event 82
# 16 channels are above 1000 in event 83
# 5 channels are above 1000 in event 85
# 1 channels are above 1000 in event 86
# 2 channels are above 1000 in event 88
# 3 channels are above 1000 in event 90
# 5 channels are above 1000 in event 92
# 6 channels are above 1000 in event 93
# 10 channels are above 1000 in event 95
# 51 out of 96 events have at least one waveform that goes above 1000
#
# file 14
# 12 channels are above 1000 in event 0
# 1 channels are above 1000 in event 1
# 1 channels are above 1000 in event 3
# 7 channels are above 1000 in event 4
# 2 channels are above 1000 in event 7
# 8 channels are above 1000 in event 9
# 7 channels are above 1000 in event 10
# 4 channels are above 1000 in event 12
# 9 channels are above 1000 in event 13
# 2 channels are above 1000 in event 17
# 3 channels are above 1000 in event 18
# 3 channels are above 1000 in event 19
# 1 channels are above 1000 in event 23
# 5 channels are above 1000 in event 26
# 2 channels are above 1000 in event 27
# 1 channels are above 1000 in event 30
# 3 channels are above 1000 in event 32
# 2 channels are above 1000 in event 34
# 2 channels are above 1000 in event 35
# 7 channels are above 1000 in event 37
# 11 channels are above 1000 in event 38
# 6 channels are above 1000 in event 40
# 4 channels are above 1000 in event 43
# 13 channels are above 1000 in event 44
# 3 channels are above 1000 in event 45
# 7 channels are above 1000 in event 48
# 8 channels are above 1000 in event 50
# 7 channels are above 1000 in event 54
# 5 channels are above 1000 in event 55
# 2 channels are above 1000 in event 59
# 9 channels are above 1000 in event 60
# 1 channels are above 1000 in event 61
# 9 channels are above 1000 in event 72
# 2 channels are above 1000 in event 75
# 2 channels are above 1000 in event 77
# 1 channels are above 1000 in event 78
# 2 channels are above 1000 in event 79
# 2 channels are above 1000 in event 80
# 2 channels are above 1000 in event 82
# 6 channels are above 1000 in event 86
# 9 channels are above 1000 in event 87
# 12 channels are above 1000 in event 90
# 7 channels are above 1000 in event 92
# 6 channels are above 1000 in event 94
# 3 channels are above 1000 in event 95
# 4 channels are above 1000 in event 96
# 7 channels are above 1000 in event 97
# 11 channels are above 1000 in event 98
# 16 channels are above 1000 in event 99
# 23 channels are above 1000 in event 100
# 10 channels are above 1000 in event 101
# 51 out of 103 events have at least one waveform that goes above 1000
#
# file 15
# 4 channels are above 1000 in event 0
# 14 channels are above 1000 in event 1
# 6 channels are above 1000 in event 2
# 1 channels are above 1000 in event 4
# 3 channels are above 1000 in event 9
# 9 channels are above 1000 in event 13
# 1 channels are above 1000 in event 14
# 5 channels are above 1000 in event 15
# 6 channels are above 1000 in event 16
# 1 channels are above 1000 in event 17
# 1 channels are above 1000 in event 21
# 11 channels are above 1000 in event 23
# 10 channels are above 1000 in event 25
# 3 channels are above 1000 in event 27
# 16 channels are above 1000 in event 28
# 3 channels are above 1000 in event 29
# 4 channels are above 1000 in event 31
# 6 channels are above 1000 in event 36
# 1 channels are above 1000 in event 37
# 6 channels are above 1000 in event 40
# 9 channels are above 1000 in event 42
# 3 channels are above 1000 in event 43
# 5 channels are above 1000 in event 44
# 4 channels are above 1000 in event 45
# 10 channels are above 1000 in event 47
# 7 channels are above 1000 in event 48
# 7 channels are above 1000 in event 51
# 3 channels are above 1000 in event 52
# 4 channels are above 1000 in event 53
# 5 channels are above 1000 in event 56
# 4 channels are above 1000 in event 58
# 12 channels are above 1000 in event 59
# 4 channels are above 1000 in event 62
# 15 channels are above 1000 in event 63
# 4 channels are above 1000 in event 64
# 4 channels are above 1000 in event 69
# 1 channels are above 1000 in event 70
# 2 channels are above 1000 in event 71
# 10 channels are above 1000 in event 77
# 1 channels are above 1000 in event 79
# 14 channels are above 1000 in event 81
# 1 channels are above 1000 in event 85
# 4 channels are above 1000 in event 88
# 3 channels are above 1000 in event 89
# 6 channels are above 1000 in event 91
# 45 out of 94 events have at least one waveform that goes above 1000
#
# file 16
# 18 channels are above 1000 in event 0
# 3 channels are above 1000 in event 1
# 1 channels are above 1000 in event 2
# 1 channels are above 1000 in event 5
# 21 channels are above 1000 in event 6
# 3 channels are above 1000 in event 9
# 5 channels are above 1000 in event 10
# 2 channels are above 1000 in event 13
# 1 channels are above 1000 in event 15
# 8 channels are above 1000 in event 16
# 3 channels are above 1000 in event 18
# 3 channels are above 1000 in event 23
# 9 channels are above 1000 in event 24
# 7 channels are above 1000 in event 29
# 9 channels are above 1000 in event 32
# 6 channels are above 1000 in event 38
# 5 channels are above 1000 in event 39
# 12 channels are above 1000 in event 40
# 7 channels are above 1000 in event 47
# 2 channels are above 1000 in event 51
# 1 channels are above 1000 in event 53
# 16 channels are above 1000 in event 54
# 3 channels are above 1000 in event 56
# 2 channels are above 1000 in event 58
# 1 channels are above 1000 in event 59
# 10 channels are above 1000 in event 62
# 4 channels are above 1000 in event 63
# 18 channels are above 1000 in event 64
# 4 channels are above 1000 in event 66
# 10 channels are above 1000 in event 70
# 2 channels are above 1000 in event 74
# 1 channels are above 1000 in event 77
# 7 channels are above 1000 in event 79
# 4 channels are above 1000 in event 82
# 3 channels are above 1000 in event 89
# 5 channels are above 1000 in event 90
# 4 channels are above 1000 in event 93
# 12 channels are above 1000 in event 94
# 9 channels are above 1000 in event 95
# 1 channels are above 1000 in event 97
# 9 channels are above 1000 in event 98
# 9 channels are above 1000 in event 100
# 8 channels are above 1000 in event 103
# 43 out of 105 events have at least one waveform that goes above 1000
#
# file 17
# 8 channels are above 1000 in event 0
# 1 channels are above 1000 in event 1
# 2 channels are above 1000 in event 4
# 1 channels are above 1000 in event 9
# 5 channels are above 1000 in event 10
# 1 channels are above 1000 in event 14
# 1 channels are above 1000 in event 15
# 5 channels are above 1000 in event 22
# 7 channels are above 1000 in event 25
# 6 channels are above 1000 in event 26
# 8 channels are above 1000 in event 27
# 10 channels are above 1000 in event 28
# 9 channels are above 1000 in event 29
# 20 channels are above 1000 in event 30
# 12 channels are above 1000 in event 32
# 14 channels are above 1000 in event 33
# 1 channels are above 1000 in event 39
# 4 channels are above 1000 in event 42
# 13 channels are above 1000 in event 47
# 1 channels are above 1000 in event 53
# 3 channels are above 1000 in event 54
# 1 channels are above 1000 in event 56
# 12 channels are above 1000 in event 57
# 8 channels are above 1000 in event 61
# 5 channels are above 1000 in event 62
# 18 channels are above 1000 in event 63
# 1 channels are above 1000 in event 64
# 2 channels are above 1000 in event 65
# 1 channels are above 1000 in event 68
# 7 channels are above 1000 in event 70
# 12 channels are above 1000 in event 76
# 8 channels are above 1000 in event 77
# 10 channels are above 1000 in event 79
# 1 channels are above 1000 in event 80
# 16 channels are above 1000 in event 84
# 1 channels are above 1000 in event 86
# 3 channels are above 1000 in event 89
# 1 channels are above 1000 in event 94
# 4 channels are above 1000 in event 98
# 17 channels are above 1000 in event 99
# 5 channels are above 1000 in event 102
# 41 out of 104 events have at least one waveform that goes above 1000
#
# file 18
# 3 channels are above 1000 in event 2
# 10 channels are above 1000 in event 6
# 1 channels are above 1000 in event 7
# 5 channels are above 1000 in event 11
# 11 channels are above 1000 in event 14
# 4 channels are above 1000 in event 19
# 6 channels are above 1000 in event 21
# 10 channels are above 1000 in event 27
# 1 channels are above 1000 in event 28
# 11 channels are above 1000 in event 30
# 1 channels are above 1000 in event 31
# 4 channels are above 1000 in event 34
# 21 channels are above 1000 in event 35
# 16 channels are above 1000 in event 39
# 5 channels are above 1000 in event 40
# 6 channels are above 1000 in event 41
# 2 channels are above 1000 in event 46
# 1 channels are above 1000 in event 49
# 16 channels are above 1000 in event 50
# 4 channels are above 1000 in event 51
# 6 channels are above 1000 in event 52
# 4 channels are above 1000 in event 53
# 7 channels are above 1000 in event 55
# 7 channels are above 1000 in event 56
# 5 channels are above 1000 in event 60
# 1 channels are above 1000 in event 61
# 23 channels are above 1000 in event 63
# 9 channels are above 1000 in event 66
# 7 channels are above 1000 in event 70
# 11 channels are above 1000 in event 71
# 14 channels are above 1000 in event 72
# 2 channels are above 1000 in event 74
# 4 channels are above 1000 in event 79
# 7 channels are above 1000 in event 83
# 16 channels are above 1000 in event 87
# 1 channels are above 1000 in event 89
# 2 channels are above 1000 in event 90
# 7 channels are above 1000 in event 91
# 7 channels are above 1000 in event 92
# 11 channels are above 1000 in event 93
# 1 channels are above 1000 in event 94
# 41 out of 95 events have at least one waveform that goes above 1000
#
# file 19
# 5 channels are above 1000 in event 1
# 4 channels are above 1000 in event 2
# 6 channels are above 1000 in event 3
# 1 channels are above 1000 in event 7
# 10 channels are above 1000 in event 8
# 10 channels are above 1000 in event 10
# 3 channels are above 1000 in event 13
# 2 channels are above 1000 in event 14
# 2 channels are above 1000 in event 16
# 1 channels are above 1000 in event 17
# 29 channels are above 1000 in event 19
# 20 channels are above 1000 in event 20
# 4 channels are above 1000 in event 21
# 6 channels are above 1000 in event 22
# 4 channels are above 1000 in event 24
# 2 channels are above 1000 in event 25
# 3 channels are above 1000 in event 27
# 20 channels are above 1000 in event 28
# 4 channels are above 1000 in event 33
# 8 channels are above 1000 in event 34
# 4 channels are above 1000 in event 36
# 2 channels are above 1000 in event 37
# 9 channels are above 1000 in event 38
# 8 channels are above 1000 in event 40
# 3 channels are above 1000 in event 43
# 3 channels are above 1000 in event 44
# 8 channels are above 1000 in event 46
# 6 channels are above 1000 in event 47
# 10 channels are above 1000 in event 49
# 14 channels are above 1000 in event 50
# 17 channels are above 1000 in event 51
# 8 channels are above 1000 in event 52
# 1 channels are above 1000 in event 54
# 23 channels are above 1000 in event 55
# 2 channels are above 1000 in event 56
# 6 channels are above 1000 in event 57
# 1 channels are above 1000 in event 58
# 7 channels are above 1000 in event 59
# 17 channels are above 1000 in event 62
# 1 channels are above 1000 in event 64
# 1 channels are above 1000 in event 65
# 3 channels are above 1000 in event 66
# 8 channels are above 1000 in event 72
# 4 channels are above 1000 in event 73
# 12 channels are above 1000 in event 75
# 6 channels are above 1000 in event 76
# 5 channels are above 1000 in event 77
# 1 channels are above 1000 in event 84
# 32 channels are above 1000 in event 85
# 10 channels are above 1000 in event 88
# 6 channels are above 1000 in event 90
# 51 out of 93 events have at least one waveform that goes above 1000

# %%
# Path and filenames
path = '/global/cfs/cdirs/dune/users/lmlepin/2x2_neutron_prod/AmBe_prod_out_cryo_side_v1/FLOW/'
filename = '2x2_MyQGSP_BERT_ArHP_AmBe_AmBe_prod_out_cryo_top_mod0_v1_{num}.FLOW.hdf5'

# Trigger threshold
threshold = 1000

# To collect all dz values
dz_all = []

# Loop over files
for file_idx in range(0, 20):
    print(f'File {file_idx}')
    try:
        file = h5flow.data.H5FlowDataManager(path + filename.format(num=file_idx), "r")

        # Geometry (z of light traps)
        z_lcm = file['geometry_info/det_bounds/data']['data'][:, 0, 2]  # (129,)

        # Vertex positions
        z_verts = file['mc_truth/interactions/data']['z_vert'][:]  # (N_events,)

        for evt in range(len(file['light/wvfm/data'])):
            try:
                wvfm = thd_correct(file['light/wvfm/data']['samples'])[evt]  # shape (8, 64)
                z_vert = z_verts[evt]

                for j in range(8):
                    for k in range(64):
                        if np.max(wvfm[j, k]) > threshold:
                            ch_index = j * 64 + k

                            # Estimate which LCM this belongs to
                            trap_index = ch_index // 6

                            if trap_index >= len(z_lcm):
                                continue

                            dz = abs(z_lcm[trap_index] - z_vert)
                            dz_all.append(dz)

            except:
                continue

    except Exception as e:
        print(f'Could not open or process file {file_idx}: {e}')
        continue

# Plot result
plt.hist(dz_all, bins=100)
plt.xlim(0,60)
plt.ylim(0, 150)
plt.xlabel("z-distance between interaction and light trap [cm]")
plt.ylabel("Number of triggered channels")
# plt.title("Self-triggering vs. z-distance")
plt.grid(True)
plt.show()
# Out:
# File 0
# File 1

# %%
def coord_in_tpc(x, y, z):
    if y < (-46.53 + -15.51) or y > (56.87 + 5.17):
        return -1
    if z < 0 and z > -2*31.49:
        if x < -33.5 and x > -2*33.5:
            return 8
        if x < 0 and x > -33.5:
            return 7
        if x < 33.5 and x > 0:
            return 4
        if x < 2*33.5 and x > 33.5:
            return 3
    elif z > 0 and z < 2*31.49:
        if x < -33.5 and x > -2*33.5:
            return 6
        if x < 0 and x > -33.5:
            return 5
        if x < 33.5 and x > 0:
            return 2
        if x < 2*33.5 and x > 33.5:
            return 1
    return -1  # catch all other cases (like z == 0)

# %%
# Count number of hits per event
from collections import Counter
path = '/global/cfs/cdirs/dune/users/lmlepin/2x2_neutron_prod/DTG_prod_v3/FLOW/'
# path = '/global/cfs/cdirs/dune/users/lmlepin/2x2_neutron_prod/AmBe_prod_out_cryo_side_v1/FLOW/'
filename = '2x2_MyQGSP_BERT_ArHP_PNS_DTG_prod_v3_{num}.FLOW.hdf5'
# filename = '2x2_MyQGSP_BERT_ArHP_AmBe_AmBe_prod_out_cryo_top_mod0_v1_{num}.FLOW.hdf5'

threshold = 1000
min_hits_required = 0
z_locations = np.array([-60, -1, 1, 60])  # known LCM z positions

z_distances = []
triggered = []

z_distances_per_tpc = {i: [] for i in range(1, 9)}
triggered_per_tpc = {i: [] for i in range(1, 9)}

for file_idx in range(0, 100):
    print(f'File {file_idx}')
    try:
        file = h5flow.data.H5FlowDataManager(path + filename.format(num=file_idx), "r")

        # Get all hits' event IDs
        hit_event_ids = file['charge/calib_final_hits/data']['id'][:]
        hit_counts = Counter(hit_event_ids)  # maps event_id -> hit count
        traj = file['mc_truth/trajectories/data']
        pdg_id = traj['pdg_id'][:]
        end_proc = traj['end_process'][:]
        end_subproc = traj['end_subprocess'][:]
        end_z = traj['xyz_end'][:]
        event_ids = traj['event_id'][:]

        # Find indices of captured neutrons
        is_neutron = pdg_id == 2112
        is_capture = (end_proc == 4) & (end_subproc == 131)
        is_valid = is_neutron & is_capture # 

        capture_z_per_event = {}
        for evt, z in zip(event_ids[is_valid], end_z[is_valid]):
            if evt not in capture_z_per_event:
                capture_z_per_event[evt] = z  # use first found if multiple
        print(f"{len(capture_z_per_event)} capture events found in file {file_idx}")
        # z_verts = file['mc_truth/interactions/data']['z_vert'][:]
        # z_verts = file['charge/calib_final_hits/data']['z'][:]

        data = thd_correct(file['light/wvfm/data']['samples'])

        for evt in range(len(data)):
            # try:
            if hit_counts[evt] < min_hits_required:
                continue  # skip this event if not enough hits
            if np.unique(event_ids)[evt] not in event_ids[is_valid]:
                continue  # skip if no capture
            coord = capture_z_per_event[np.unique(event_ids)[evt]]
            x, y, z = coord
            z_vert = z
            tpc = coord_in_tpc(x, y, z)
            if tpc == -1:
                continue

            nearest_z = z_locations[np.argmin(np.abs(z_locations - z))]
            dz = abs(z - nearest_z)

            wvfm = data[evt]
            event_triggered = np.any(wvfm > threshold)

            z_distances_per_tpc[tpc].append(dz)
            triggered_per_tpc[tpc].append(event_triggered)

            z_distances.append(dz)
            triggered.append(event_triggered)

                # except Exception as e:
                #     print("error:", e)
                    # continue


    except Exception as e:
        print(f'Error in file {file_idx}: {e}')
        continue

# Convert to arrays
z_distances = np.array(z_distances)
triggered = np.array(triggered)

# Bin efficiency vs. z-distance
bins = np.linspace(0, 30, 30)  # 2 cm bins up to 30 cm
bin_centers = 0.5 * (bins[:-1] + bins[1:])
efficiencies = []
num = []
denom = []
errors = []

for i in range(len(bins) - 1):
    in_bin = (z_distances >= bins[i]) & (z_distances < bins[i + 1])
    n_total = np.sum(in_bin)
    n_triggered = np.sum(triggered[in_bin])

    if n_total > 0:
        eff = n_triggered / n_total
        err = np.sqrt(eff * (1 - eff) / n_total)
    else:
        eff = 0
        err = 0

    efficiencies.append(eff)
    errors.append(err)
    num.append(n_triggered)
    denom.append(n_total)
# Out:
# File 0
# 100 capture events found in file 0
# File 1
# 100 capture events found in file 1
# File 2
# 101 capture events found in file 2
# File 3
# 100 capture events found in file 3
# File 4
# 96 capture events found in file 4
# File 5
# 101 capture events found in file 5
# File 6
# 101 capture events found in file 6
# File 7
# 102 capture events found in file 7
# File 8
# 101 capture events found in file 8
# File 9
# 101 capture events found in file 9
# File 10
# 100 capture events found in file 10
# File 11
# 100 capture events found in file 11
# File 12
# 103 capture events found in file 12
# File 13
# 102 capture events found in file 13
# File 14
# 98 capture events found in file 14
# File 15
# 96 capture events found in file 15
# File 16
# 97 capture events found in file 16
# File 17
# 101 capture events found in file 17
# File 18
# 102 capture events found in file 18
# File 19
# 104 capture events found in file 19
# File 20
# 102 capture events found in file 20
# File 21
# 102 capture events found in file 21
# File 22
# 102 capture events found in file 22
# File 23
# 102 capture events found in file 23
# File 24
# 100 capture events found in file 24
# File 25
# 101 capture events found in file 25
# File 26
# 99 capture events found in file 26
# File 27
# 101 capture events found in file 27
# File 28
# 99 capture events found in file 28
# File 29
# 100 capture events found in file 29
# File 30
# 101 capture events found in file 30
# File 31
# 100 capture events found in file 31
# File 32
# 101 capture events found in file 32
# File 33
# 103 capture events found in file 33
# File 34
# 98 capture events found in file 34
# File 35
# 98 capture events found in file 35
# File 36
# 100 capture events found in file 36
# File 37
# 103 capture events found in file 37
# File 38
# 104 capture events found in file 38
# File 39
# 100 capture events found in file 39
# File 40
# 105 capture events found in file 40
# File 41
# 101 capture events found in file 41
# File 42
# 99 capture events found in file 42
# File 43
# 99 capture events found in file 43
# File 44
# 101 capture events found in file 44
# File 45
# 101 capture events found in file 45
# File 46
# 96 capture events found in file 46
# File 47
# 102 capture events found in file 47
# File 48
# 98 capture events found in file 48
# File 49
# 98 capture events found in file 49
# File 50
# 97 capture events found in file 50
# File 51
# 102 capture events found in file 51
# File 52
# 100 capture events found in file 52
# File 53
# 99 capture events found in file 53
# File 54
# 104 capture events found in file 54
# File 55
# 103 capture events found in file 55
# File 56
# 100 capture events found in file 56
# File 57
# 104 capture events found in file 57
# File 58
# 103 capture events found in file 58
# File 59
# 104 capture events found in file 59
# File 60
# 98 capture events found in file 60
# File 61
# 98 capture events found in file 61
# File 62
# 106 capture events found in file 62
# File 63
# 99 capture events found in file 63
# File 64
# 102 capture events found in file 64
# File 65
# 99 capture events found in file 65
# File 66
# 105 capture events found in file 66
# File 67
# 99 capture events found in file 67
# File 68
# 100 capture events found in file 68
# File 69
# 104 capture events found in file 69
# File 70
# 102 capture events found in file 70
# File 71
# 101 capture events found in file 71
# File 72
# 98 capture events found in file 72
# File 73
# 102 capture events found in file 73
# File 74
# 103 capture events found in file 74
# File 75
# 100 capture events found in file 75
# File 76
# 100 capture events found in file 76
# File 77
# 102 capture events found in file 77
# File 78
# 103 capture events found in file 78
# File 79
# 105 capture events found in file 79
# File 80
# 103 capture events found in file 80
# File 81
# 108 capture events found in file 81
# File 82
# 105 capture events found in file 82
# File 83
# 100 capture events found in file 83
# File 84
# 99 capture events found in file 84
# File 85
# 99 capture events found in file 85
# File 86
# 100 capture events found in file 86
# File 87
# 99 capture events found in file 87
# File 88
# 102 capture events found in file 88
# File 89
# 98 capture events found in file 89
# File 90
# 101 capture events found in file 90
# File 91
# 105 capture events found in file 91
# File 92
# 101 capture events found in file 92
# File 93
# 105 capture events found in file 93
# File 94
# 100 capture events found in file 94
# File 95
# 101 capture events found in file 95
# File 96
# 103 capture events found in file 96
# File 97
# 101 capture events found in file 97
# File 98
# 104 capture events found in file 98
# File 99
# 99 capture events found in file 99

# %%
plt.errorbar(bin_centers, efficiencies, yerr=errors, fmt='o', label='Efficiency', capsize=3, color='blue')
# plt.plot(bin_centers, num, marker='s', label='Triggered Events', color='red')
# plt.plot(bin_centers, denom, marker='.', label='Total Events', color='orange')
plt.xlabel("Distance to nearest light trap [cm]")
plt.ylabel("Trigger efficiency (> 1000 ADC counts)")
plt.title("Light self-trigger efficiency vs. z-distance, n_hits >= 0")
# plt.ylim(-0.02, 0.1)
plt.legend()
plt.show()

print(np.mean(eff))
# Out:
# 0.9795918367346939

# %%
for tpc in range(1, 9):
    z_distances = np.array(z_distances_per_tpc[tpc])
    triggered = np.array(triggered_per_tpc[tpc])
    
    efficiencies = []
    errors = []

    for i in range(len(bins) - 1):
        in_bin = (z_distances >= bins[i]) & (z_distances < bins[i + 1])
        n_total = np.sum(in_bin)
        n_triggered = np.sum(triggered[in_bin])

        if n_total > 0:
            eff = n_triggered / n_total
            err = np.sqrt(eff * (1 - eff) / n_total)
        else:
            eff = 0
            err = 0

        efficiencies.append(eff)
        errors.append(err)

    plt.errorbar(bin_centers, efficiencies, yerr=errors, label=f'TPC {tpc}', fmt='o', capsize=3, alpha=0.5)

plt.xlabel("Distance to nearest light trap [cm]")
plt.ylabel("Trigger efficiency (> 1000 ADC counts)")
plt.title("Light self-trigger efficiency vs. z-distance")
plt.legend()
# plt.ylim(-0.05, 0.3)
plt.show()

# %%
capture_z_per_event.values()
# Out:
# dict_values([np.float32(-43.80473), np.float32(40.513927), np.float32(189.97879), np.float32(-2.6690161), np.float32(-87.93903), np.float32(-50.951492), np.float32(-36.170753), np.float32(21.392109), np.float32(-2.396278), np.float32(-1.8515534), np.float32(103.506645), np.float32(174.65741), np.float32(195.15276), np.float32(5.000098), np.float32(-22.457653), np.float32(46.010662), np.float32(36.824192), np.float32(-46.3161), np.float32(-30.361486), np.float32(-7.2517853), np.float32(-190.11697), np.float32(-2.0477262), np.float32(-41.016926), np.float32(4.357739), np.float32(185.4767), np.float32(-23.443851), np.float32(37.758404), np.float32(-187.1262), np.float32(76.25465), np.float32(-86.61605), np.float32(62.207973), np.float32(-37.975742), np.float32(48.59331), np.float32(7.875916), np.float32(65.86879), np.float32(37.473465), np.float32(-13.011522), np.float32(103.31033), np.float32(65.40912), np.float32(-33.722687), np.float32(-63.898254), np.float32(-21.77467), np.float32(-10.319571), np.float32(-54.233517), np.float32(109.2999), np.float32(-45.760406), np.float32(172.69426), np.float32(-27.756329), np.float32(-38.067364), np.float32(-188.79494), np.float32(-48.446568), np.float32(-94.774), np.float32(-80.94336), np.float32(37.777096), np.float32(-58.684715), np.float32(82.49957), np.float32(165.61185), np.float32(-100.13675), np.float32(4.046409), np.float32(87.15845), np.float32(59.40654), np.float32(168.68355), np.float32(167.72722), np.float32(207.1398), np.float32(77.85381), np.float32(0.049843717), np.float32(-30.215998), np.float32(41.98521), np.float32(35.31144), np.float32(13.435126), np.float32(-193.11073), np.float32(-20.533787), np.float32(197.75359), np.float32(-49.33434), np.float32(201.74675), np.float32(180.98898), np.float32(19.179022), np.float32(66.40869), np.float32(181.60866), np.float32(186.5525), np.float32(-95.87645), np.float32(171.88617), np.float32(65.69028), np.float32(99.01482), np.float32(209.68198), np.float32(-37.09575), np.float32(-12.402768), np.float32(-25.65693), np.float32(169.11542), np.float32(-2.4088795), np.float32(-186.78079), np.float32(26.835371), np.float32(-201.97293), np.float32(171.77483), np.float32(191.8844), np.float32(94.773674), np.float32(99.1857), np.float32(-0.5503509), np.float32(-54.34352)])

# %%
# let's plot vertex positions
fig, ax = plt.subplots(1, 1, figsize=(5, 5))
# ax.scatter(file['mc_truth/interactions/data']['z_vert'], 
#            file['mc_truth/interactions/data']['y_vert'], 
#             s=10, alpha=0.2)
# ax.scatter(file['charge/calib_final_hits/data']['z'], 
#            file['charge/calib_final_hits/data']['y'], 
#             s=10, alpha=0.2) 
ax.hist(capture_z_per_event.values())
plt.xlim(-60, 60)
plt.ylim(-60, 60)
plt.xlabel('Z [cm]')
plt.ylabel('X [cm]')
plt.title('Hit positions')
print(len(file['charge/events/data']))
# Out:
# 108

# %%
# now lets do this for some files
path = '/global/cfs/cdirs/dune/users/lmlepin/2x2_neutron_prod/PNS_prod_V1/FLOW/'
filename = '2x2_MyQGSP_BERT_ArHP_DTG_PNS_prod_V1_{num}.FLOW.hdf5'

for i in range(0, 20):
    print('file', i)
    file = h5flow.data.H5FlowDataManager(path + filename.format(num=i), "r")
    try:
        a = file["light/wvfm/data"]['samples']
        threshold = 4000
        n = 0
        summary = {}
        for i in range(len(file['light/wvfm/data'])):
            if np.max(file['light/wvfm/data'][i]['samples']) > threshold:
                n += 1
                # count how many channels are above threshold
                l = 0
                for j in range(8):
                    for k in range(64):
                        if np.max(file['light/wvfm/data'][i]['samples'][j,k]) > threshold:
                            l += 1
                print(l, 'channels are above', threshold, 'in event', i)
                summary[i] = l
        print(n, 'out of', len(file['light/wvfm/data']), 'events have at least one waveform that goes above', threshold)
        print('')
    except:
        print('no data')
        print('')
# Out:
# file 0
# 2 channels are above 4000 in event 0
# 2 channels are above 4000 in event 10
# 4 channels are above 4000 in event 12
# 2 channels are above 4000 in event 13
# 2 channels are above 4000 in event 14
# 1 channels are above 4000 in event 21
# 1 channels are above 4000 in event 32
# 8 channels are above 4000 in event 45
# 2 channels are above 4000 in event 49
# 2 channels are above 4000 in event 71
# 1 channels are above 4000 in event 85
# 4 channels are above 4000 in event 93
# 12 out of 108 events have at least one waveform that goes above 4000
#
# file 1
# 2 channels are above 4000 in event 2
# 1 channels are above 4000 in event 6
# 3 channels are above 4000 in event 14
# 5 channels are above 4000 in event 18
# 4 channels are above 4000 in event 28
# 8 channels are above 4000 in event 30
# 2 channels are above 4000 in event 37
# 1 channels are above 4000 in event 56
# 2 channels are above 4000 in event 60
# 2 channels are above 4000 in event 69
# 1 channels are above 4000 in event 77
# 1 channels are above 4000 in event 82
# 2 channels are above 4000 in event 87
# 13 out of 99 events have at least one waveform that goes above 4000
#
# file 2
# 1 channels are above 4000 in event 1
# 1 channels are above 4000 in event 3
# 3 channels are above 4000 in event 8
# 1 channels are above 4000 in event 20
# 1 channels are above 4000 in event 21
# 2 channels are above 4000 in event 22
# 1 channels are above 4000 in event 29
# 4 channels are above 4000 in event 34
# 8 channels are above 4000 in event 46
# 1 channels are above 4000 in event 51
# 1 channels are above 4000 in event 52
# 1 channels are above 4000 in event 53
# 1 channels are above 4000 in event 55
# 2 channels are above 4000 in event 85
# 14 out of 100 events have at least one waveform that goes above 4000
#
# file 3
# 7 channels are above 4000 in event 7
# 3 channels are above 4000 in event 12
# 4 channels are above 4000 in event 13
# 1 channels are above 4000 in event 14
# 1 channels are above 4000 in event 16
# 1 channels are above 4000 in event 26
# 6 channels are above 4000 in event 30
# 6 channels are above 4000 in event 36
# 1 channels are above 4000 in event 49
# 3 channels are above 4000 in event 53
# 2 channels are above 4000 in event 66
# 1 channels are above 4000 in event 79
# 1 channels are above 4000 in event 89
# 1 channels are above 4000 in event 94
# 1 channels are above 4000 in event 95
# 1 channels are above 4000 in event 97
# 2 channels are above 4000 in event 98
# 7 channels are above 4000 in event 101
# 18 out of 102 events have at least one waveform that goes above 4000
#
# file 4
# 1 channels are above 4000 in event 2
# 3 channels are above 4000 in event 5
# 1 channels are above 4000 in event 6
# 4 channels are above 4000 in event 9
# 1 channels are above 4000 in event 12
# 1 channels are above 4000 in event 16
# 2 channels are above 4000 in event 27
# 3 channels are above 4000 in event 38
# 1 channels are above 4000 in event 42
# 3 channels are above 4000 in event 44
# 1 channels are above 4000 in event 49
# 10 channels are above 4000 in event 73
# 3 channels are above 4000 in event 79
# 3 channels are above 4000 in event 80
# 5 channels are above 4000 in event 87
# 2 channels are above 4000 in event 91
# 4 channels are above 4000 in event 92
# 17 out of 96 events have at least one waveform that goes above 4000
#
# file 5
# 2 channels are above 4000 in event 1
# 2 channels are above 4000 in event 33
# 4 channels are above 4000 in event 39
# 2 channels are above 4000 in event 46
# 2 channels are above 4000 in event 53
# 2 channels are above 4000 in event 58
# 4 channels are above 4000 in event 59
# 1 channels are above 4000 in event 60
# 2 channels are above 4000 in event 67
# 1 channels are above 4000 in event 78
# 1 channels are above 4000 in event 80
# 2 channels are above 4000 in event 90
# 3 channels are above 4000 in event 93
# 1 channels are above 4000 in event 98
# 14 out of 101 events have at least one waveform that goes above 4000
#
# file 6
# 2 channels are above 4000 in event 8
# 2 channels are above 4000 in event 32
# 1 channels are above 4000 in event 47
# 2 channels are above 4000 in event 49
# 1 channels are above 4000 in event 52
# 5 channels are above 4000 in event 58
# 3 channels are above 4000 in event 80
# 8 channels are above 4000 in event 82
# 1 channels are above 4000 in event 89
# 3 channels are above 4000 in event 97
# 6 channels are above 4000 in event 100
# 11 out of 102 events have at least one waveform that goes above 4000
#
# file 7
# 4 channels are above 4000 in event 5
# 6 channels are above 4000 in event 18
# 4 channels are above 4000 in event 40
# 1 channels are above 4000 in event 62
# 1 channels are above 4000 in event 67
# 3 channels are above 4000 in event 78
# 1 channels are above 4000 in event 83
# 4 channels are above 4000 in event 95
# 8 out of 99 events have at least one waveform that goes above 4000
#
# file 8
# 8 channels are above 4000 in event 12
# 1 channels are above 4000 in event 18
# 3 channels are above 4000 in event 20
# 2 channels are above 4000 in event 24
# 2 channels are above 4000 in event 36
# 3 channels are above 4000 in event 45
# 1 channels are above 4000 in event 49
# 3 channels are above 4000 in event 52
# 1 channels are above 4000 in event 59
# 4 channels are above 4000 in event 62
# 1 channels are above 4000 in event 68
# 2 channels are above 4000 in event 79
# 3 channels are above 4000 in event 87
# 13 out of 100 events have at least one waveform that goes above 4000
#
# file 9
# 4 channels are above 4000 in event 5
# 2 channels are above 4000 in event 6
# 1 channels are above 4000 in event 22
# 4 channels are above 4000 in event 25
# 3 channels are above 4000 in event 26
# 6 channels are above 4000 in event 27
# 3 channels are above 4000 in event 31
# 3 channels are above 4000 in event 48
# 3 channels are above 4000 in event 62
# 3 channels are above 4000 in event 68
# 1 channels are above 4000 in event 76
# 5 channels are above 4000 in event 77
# no data
#
# file 10
# no data
#
# file 11
# 1 channels are above 4000 in event 4
# 1 channels are above 4000 in event 10
# 1 channels are above 4000 in event 13
# 2 channels are above 4000 in event 14
# 4 channels are above 4000 in event 20
# 1 channels are above 4000 in event 22
# 8 channels are above 4000 in event 39
# 1 channels are above 4000 in event 41
# 2 channels are above 4000 in event 43
# 3 channels are above 4000 in event 57
# 2 channels are above 4000 in event 87
# 6 channels are above 4000 in event 98
# 12 out of 100 events have at least one waveform that goes above 4000
#
# file 12
# 1 channels are above 4000 in event 4
# 1 channels are above 4000 in event 13
# 2 channels are above 4000 in event 22
# 2 channels are above 4000 in event 24
# 1 channels are above 4000 in event 34
# 2 channels are above 4000 in event 39
# 1 channels are above 4000 in event 41
# 5 channels are above 4000 in event 43
# 1 channels are above 4000 in event 45
# 5 channels are above 4000 in event 63
# 3 channels are above 4000 in event 73
# 2 channels are above 4000 in event 81
# 1 channels are above 4000 in event 83
# 2 channels are above 4000 in event 88
# 1 channels are above 4000 in event 98
# 1 channels are above 4000 in event 101
# 2 channels are above 4000 in event 103
# 17 out of 104 events have at least one waveform that goes above 4000
#
# file 13
# 1 channels are above 4000 in event 11
# 1 channels are above 4000 in event 33
# 3 channels are above 4000 in event 37
# 2 channels are above 4000 in event 44
# 2 channels are above 4000 in event 47
# 1 channels are above 4000 in event 56
# 4 channels are above 4000 in event 71
# 1 channels are above 4000 in event 75
# 1 channels are above 4000 in event 77
# 1 channels are above 4000 in event 80
# 1 channels are above 4000 in event 83
# 1 channels are above 4000 in event 88
# 12 out of 96 events have at least one waveform that goes above 4000
#
# file 14
# 5 channels are above 4000 in event 0
# 2 channels are above 4000 in event 4
# 1 channels are above 4000 in event 12
# 3 channels are above 4000 in event 13
# 1 channels are above 4000 in event 37
# 2 channels are above 4000 in event 38
# 1 channels are above 4000 in event 43
# 3 channels are above 4000 in event 44
# 2 channels are above 4000 in event 48
# 4 channels are above 4000 in event 54
# 1 channels are above 4000 in event 87
# 1 channels are above 4000 in event 90
# 1 channels are above 4000 in event 97
# 1 channels are above 4000 in event 99
# 3 channels are above 4000 in event 100
# 15 out of 103 events have at least one waveform that goes above 4000
#
# file 15
# 6 channels are above 4000 in event 1
# 2 channels are above 4000 in event 2
# 4 channels are above 4000 in event 23

# %%
# Define path and filename pattern
path = '/global/cfs/cdirs/dune/users/lmlepin/2x2_neutron_prod/AmBe_Prod_V2/FLOW/'
filename = '2x2_MyQGSP_BERT_ArHP_AmBe_AmBe_Prod_V2_{num}.FLOW.hdf5'

# Threshold definition
threshold = 1500

# Storage for statistics
file_indices = []
num_above_threshold = []
channel_counts = []
total_events = 0
total_events_above = 0

# Process files
for i in range(50):
    print('Processing file', i)
    file = h5flow.data.H5FlowDataManager(path + filename.format(num=i), "r")
    
    try:
        data = file["light/wvfm/data"]
        num_events = len(data)
        total_events += num_events
        n_above = 0
        event_channel_counts = []

        for event_idx in range(num_events):
            samples = data[event_idx]['samples']  # Shape: (8, 64)
            
            if np.max(samples) > threshold:
                n_above += 1
                total_events_above += 1  # Count every event that exceeds threshold

                l = 0
                for j in range(8):  # Loop over 8 adcs
                    for k in range(64):  # Loop over 64 channels
                        if max(samples[j, k]) > threshold:
                            l += 1  # Count every channel that exceeds threshold
                event_channel_counts.append(l)

        # Store results
        file_indices.append(i)
        num_above_threshold.append(n_above)
        channel_counts.extend(event_channel_counts)  # Store all channel counts

    except Exception as e:
        print(f"No data in file {i}: {e}")
        file_indices.append(i)
        num_above_threshold.append(0)

# Plot results
plt.figure(figsize=(10, 5))

# Bar plot: events above threshold per file
plt.subplot(1, 2, 1)
plt.bar(file_indices, num_above_threshold, color='b', alpha=0.7)
plt.xlabel("File index")
plt.ylabel("Events above threshold")
plt.title(f"Events exceeding threshold of {threshold} adc counts per AmBe file")

# Histogram: distribution of number of channels above threshold
plt.subplot(1, 2, 2)
bins = range(1, max(channel_counts) + 2)
hist_values, bin_edges, _ = plt.hist(channel_counts, bins=bins, color='r', alpha=0.7, edgecolor='black')

# Adjust x-axis ticks to be at the center of bins
bin_centers = [(bin_edges[i] + bin_edges[i+1]) / 2 for i in range(len(bin_edges)-1)]
plt.xticks(bin_centers, labels=[str(int(c)) for c in bin_centers])  # Ensure labels are integers
plt.xlabel("Channels above threshold per event")
plt.ylabel("Event count")
plt.title("Channel count distribution")

plt.tight_layout()
plt.show()

# Compute the percentage of events exceeding threshold
if total_events > 0:
    percentage_above = (total_events_above / total_events) * 100
else:
    percentage_above = 0
print(f"\nPercentage of events with at least one waveform above threshold: {percentage_above:.2f}%")
# Out:
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
# Processing file 4
# Processing file 5
# Processing file 6
# No data in file 6: 'Unable to synchronously open object (component not found)'
# Processing file 7
# Processing file 8
# Processing file 9
# Processing file 10
# Processing file 11
# Processing file 12
# Processing file 13
# Processing file 14
# Processing file 15
# Processing file 16
# Processing file 17
# Processing file 18
# Processing file 19
# Processing file 20
# Processing file 21
# Processing file 22
# Processing file 23
# Processing file 24
# Processing file 25
# Processing file 26
# Processing file 27
# Processing file 28
# Processing file 29
# Processing file 30
# Processing file 31
# Processing file 32
# Processing file 33
# Processing file 34
# Processing file 35
# Processing file 36
# Processing file 37
# Processing file 38
# Processing file 39
# Processing file 40
# Processing file 41
# Processing file 42
# Processing file 43
# Processing file 44
# Processing file 45
# Processing file 46
# Processing file 47
# Processing file 48
# Processing file 49
# Percentage of events with at least one waveform above threshold: 18.33%

# %%
# Define path and filename pattern
path = '/global/cfs/cdirs/dune/users/lmlepin/2x2_neutron_prod/PNS_prod_V1/FLOW/'
filename = '2x2_MyQGSP_BERT_ArHP_DTG_PNS_prod_V1_{num}.FLOW.hdf5'

# Threshold definition
threshold = 1500

# Storage for statistics
file_indices = []
num_above_threshold = []
channel_counts = []
total_events = 0
total_events_above = 0

# Process files
for i in range(50):
    print('Processing file', i)
    file = h5flow.data.H5FlowDataManager(path + filename.format(num=i), "r")
    
    try:
        data = file["light/wvfm/data"]
        num_events = len(data)
        total_events += num_events
        n_above = 0
        event_channel_counts = []

        for event_idx in range(num_events):
            samples = data[event_idx]['samples']  # Shape: (8, 64)
            
            if np.max(samples) > threshold:
                n_above += 1
                total_events_above += 1
                l = 0
                for j in range(8):  # Loop over 8 adcs
                    for k in range(64):  # Loop over 64 channels
                        if max(samples[j, k]) > threshold:
                            l += 1  # Count every channel that exceeds threshold
                event_channel_counts.append(l)

        # Store results
        file_indices.append(i)
        num_above_threshold.append(n_above)
        channel_counts.extend(event_channel_counts)  # Store all channel counts




    except Exception as e:
        print(f"No data in file {i}: {e}")
        file_indices.append(i)
        num_above_threshold.append(0)

# Plot results
plt.figure(figsize=(10, 5))

# Bar plot: events above threshold per file
plt.subplot(1, 2, 1)
plt.bar(file_indices, num_above_threshold, color='b', alpha=0.7)
plt.xlabel("File index")
plt.ylabel("Events above threshold")
plt.title(f"Events exceeding threshold of {threshold} adc counts per PNS file")

# Histogram: distribution of number of channels above threshold
plt.subplot(1, 2, 2)
bins = range(1, max(channel_counts) + 2)
hist_values, bin_edges, _ = plt.hist(channel_counts, bins=bins, color='r', alpha=0.7, edgecolor='black')

# Adjust x-axis ticks to be at the center of bins
bin_centers = [(bin_edges[i] + bin_edges[i+1]) / 2 for i in range(len(bin_edges)-1)]
plt.xticks(bin_centers, labels=[str(int(c)) for c in bin_centers])  # Ensure labels are integers
plt.xlabel("Channels above threshold per event")
plt.ylabel("Event count")
plt.title("Channel count distribution")

plt.tight_layout()
plt.show()


# Compute the percentage of events exceeding threshold
if total_events > 0:
    percentage_above = (total_events_above / total_events) * 100
else:
    percentage_above = 0
print(f"\nPercentage of events with at least one waveform above threshold: {percentage_above:.2f}%")
# Out:
# Processing file 0
# Processing file 1
# Processing file 2
# Processing file 3
# Processing file 4
# Processing file 5
# Processing file 6
# Processing file 7
# Processing file 8
# Processing file 9
# Processing file 10
# No data in file 10: 'Unable to synchronously open object (component not found)'
# Processing file 11
# Processing file 12
# Processing file 13
# Processing file 14
# Processing file 15
# Processing file 16
# Processing file 17
# Processing file 18
# Processing file 19
# Processing file 20
# Processing file 21
# Processing file 22
# Processing file 23
# Processing file 24
# Processing file 25
# Processing file 26
# Processing file 27
# Processing file 28
# Processing file 29
# Processing file 30
# No data in file 30: 'Unable to synchronously open object (component not found)'
# Processing file 31
# Processing file 32
# Processing file 33
# Processing file 34
# Processing file 35
# Processing file 36
# Processing file 37
# Processing file 38
# Processing file 39
# Processing file 40
# Processing file 41
# Processing file 42
# No data in file 42: 'Unable to synchronously open object (component not found)'
# Processing file 43
# Processing file 44
# Processing file 45
# No data in file 45: 'Unable to synchronously open object (component not found)'
# Processing file 46
# Processing file 47
# Processing file 48
# Processing file 49
# Percentage of events with at least one waveform above threshold: 38.12%

# %%
ambe_perc = {200: 92.58, 500: 85.29, 750: 50.12, 1000: 34.08, 1500: 18.33,  2000: 12.19, 3000: 6.69, 4000: 3.91, 5000: 2.54}
pns_perc = {200: 73.16, 500: 69.11, 750: 55.52, 1000: 49.60, 1500: 38.12, 2000: 30.49, 3000: 20.42, 4000: 14.05, 5000: 9.75}

# %%
# plot the percentates
plt.figure(figsize=(10, 5))
plt.plot(list(ambe_perc.keys()), list(ambe_perc.values()), marker='s', label='AmBe')
plt.plot(list(pns_perc.keys()), list(pns_perc.values()), marker='s', label='PNS')
plt.xlabel('Threshold [ADC counts]')
plt.ylabel('Percentage of events')
plt.title('Percentage of events with at least one waveform above threshold')
plt.legend()
plt.show()
